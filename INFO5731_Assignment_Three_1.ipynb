# %% [markdown]
# <a href="https://colab.research.google.com/github/unt-iialab/INFO5731_Spring2020/blob/master/Assignments/INFO5731_Assignment_Three.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Three**
#
# In this assignment, you are required to conduct information extraction, semantic analysis based on **the dataset you collected from assignment two**. You may use scipy and numpy package in this assignment.

# %% [markdown]
# # **Question 1: Understand N-gram**

# %% [markdown]
# (45 points). Write a python program to conduct N-gram analysis based on the dataset in your assignment two:
#
# (1) Count the frequency of all the N-grams (N=3).
#
# (2) Calculate the probabilities for all the bigrams in the dataset by using the fomular count(w2 w1) / count(w2). For example, count(really like) / count(really) = 1 / 3 = 0.33.
#
# (3) Extract all the **noun phrases** and calculate the relative probabilities of each review in terms of other reviews (abstracts, or tweets) by using the fomular frequency (noun phrase) / max frequency (noun phrase) on the whole dataset. Print out the result in a table with column name the all the noun phrases and row name as all the 100 reviews (abstracts, or tweets).

# %%
#installing selenium package
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install selenium
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [82.3 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:11 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:14 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:15 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [951 kB]
# Get:16 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:17 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [29.8 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,267 kB]
# Get:20 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,831 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,132 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [918 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-backports/main amd64 Packages [12.2 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [12.9 kB]
# Get:25 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [884 kB]
# Get:26 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,489 kB]
# Get:27 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [938 kB]
# Get:28 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,693 kB]
# Get:29 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [45.3 kB]
# Get:30 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [44.3 kB]
# Fetched 15.6 MB in 5s (3,134 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 94 not upgraded.
# Need to get 88.3 MB of archives.
# After this operation, 294 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 99.0.4844.84-0ubuntu0.18.04.1 [1,142 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser amd64 99.0.4844.84-0ubuntu0.18.04.1 [77.7 MB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser-l10n all 99.0.4844.84-0ubuntu0.18.04.1 [4,397 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-chromedriver amd64 99.0.4844.84-0ubuntu0.18.04.1 [5,092 kB]
# Fetched 88.3 MB in 3s (29.6 MB/s)
# Selecting previously unselected package chromium-codecs-ffmpeg-extra.
# (Reading database ... 156210 files and directories currently installed.)
# Preparing to unpack .../chromium-codecs-ffmpeg-extra_99.0.4844.84-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-codecs-ffmpeg-extra (99.0.4844.84-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser.
# Preparing to unpack .../chromium-browser_99.0.4844.84-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-browser (99.0.4844.84-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser-l10n.
# Preparing to unpack .../chromium-browser-l10n_99.0.4844.84-0ubuntu0.18.04.1_all.deb ...
# Unpacking chromium-browser-l10n (99.0.4844.84-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_99.0.4844.84-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-chromedriver (99.0.4844.84-0ubuntu0.18.04.1) ...
# Setting up chromium-codecs-ffmpeg-extra (99.0.4844.84-0ubuntu0.18.04.1) ...
# Setting up chromium-browser (99.0.4844.84-0ubuntu0.18.04.1) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-chromedriver (99.0.4844.84-0ubuntu0.18.04.1) ...
# Setting up chromium-browser-l10n (99.0.4844.84-0ubuntu0.18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file
# Collecting selenium
#   Downloading selenium-4.1.0-py3-none-any.whl (958 kB)
#      |████████████████████████████████| 958 kB 6.9 MB/s
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Collecting trio~=0.17
#   Downloading trio-0.19.0-py3-none-any.whl (356 kB)
#      |████████████████████████████████| 356 kB 68.4 MB/s
# Collecting urllib3[secure]~=1.26
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 44.5 MB/s
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (21.4.0)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting outcome
#   Downloading outcome-1.1.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.10)
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.0.0-py3-none-any.whl (24 kB)
# Collecting cryptography>=1.3.4
#   Downloading cryptography-36.0.1-cp36-abi3-manylinux_2_24_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 42.0 MB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from urllib3[secure]~=1.26->selenium) (2021.10.8)
# Collecting pyOpenSSL>=0.14
#   Downloading pyOpenSSL-21.0.0-py2.py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 3.9 MB/s
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=1.3.4->urllib3[secure]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3[secure]~=1.26->selenium) (2.21)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.15.0)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.13.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 6.4 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from h11<1,>=0.9.0->wsproto>=0.14->trio-websocket~=0.9->selenium) (3.10.0.2)
# Installing collected packages: sniffio, outcome, h11, cryptography, async-generator, wsproto, urllib3, trio, pyOpenSSL, trio-websocket, selenium
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.9 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed async-generator-1.10 cryptography-36.0.1 h11-0.13.0 outcome-1.1.0 pyOpenSSL-21.0.0 selenium-4.1.0 sniffio-1.2.0 trio-0.19.0 trio-websocket-0.9.2 urllib3-1.26.9 wsproto-1.0.0

# %%
from selenium import webdriver #importing selenium package
options = webdriver.ChromeOptions()
options.add_argument('-headless')
options.add_argument('-no-sandbox')
options.add_argument('-disable-dev-shm-usage')

# %%
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.common.by import By
import pandas as pd
import time

driver = webdriver.Chrome('chromedriver',options=options)
link = 'https://www.imdb.com/title/tt7286456/reviews?ref_=tt_urv'
title_array = []
review_array = []
driver.get(link)
for num in range(4):
  driver.find_element_by_class_name("ipl-load-more__button").click()
  time.sleep(5)
  listOfTitle = driver.find_elements(By.CLASS_NAME, "title")
  listOfReviews = driver.find_elements(By.CLASS_NAME, "text")
for ele, sub_ele in zip(listOfTitle, listOfReviews):
      title_array.append((ele.text).replace('\n',''))
      review_array.append(sub_ele.text)
df = pd.DataFrame(list(zip(title_array, review_array)), columns =['Title', 'Review'])
print("Length of data frame is {0}".format(len(df)))
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   if sys.path[0] == '':
# Length of data frame is 125
#                                                  Title  \
# 0    Outstanding movie with a haunting performance ...
# 1                       Only certain people can relate
# 2                             Perfect in every aspect.
# 3                                        MASTERPIECE 😍
# 4                                     The Hype is real
# ..                                                 ...
# 120                                Good, if derivative
# 121  Arthur Fleck: a case study of a young person's...
# 122  A gorgeously crafted baroque film with a sheer...
# 123  10 as a Masterpiece of a Stand-Alone Film. 5 f...
# 124              Took my 65 year old mother to see it.
#
#                                                 Review
# 0    Every once in a while a movie comes, that trul...
# 1    This is a movie that only those who have felt ...
# 2    Truly a masterpiece, The Best Hollywood film o...
# 3    Joaquin Phoenix gives a tour de force performa...
# 4    Most of the time movies are anticipated like t...
# ..                                                 ...
# 120
# 121  This film surpassed all other films in portray...
# 122  A confused representation of insanity from a p...
# 123  While we were at one of the only pre-screening...
# 124  I saw the movie after the opening weekend and ...
#
# [125 rows x 2 columns]

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> l
# Packages:
#   [ ] abc................. Australian Broadcasting Commission 2006
#   [ ] alpino.............. Alpino Dutch Treebank
#   [ ] averaged_perceptron_tagger Averaged Perceptron Tagger
#   [ ] averaged_perceptron_tagger_ru Averaged Perceptron Tagger (Russian)
#   [ ] basque_grammars..... Grammars for Basque
#   [ ] biocreative_ppi..... BioCreAtIvE (Critical Assessment of Information
#                            Extraction Systems in Biology)
#   [ ] bllip_wsj_no_aux.... BLLIP Parser: WSJ Model
#   [ ] book_grammars....... Grammars from NLTK Book
#   [ ] brown............... Brown Corpus
#   [ ] brown_tei........... Brown Corpus (TEI XML Version)
#   [ ] cess_cat............ CESS-CAT Treebank
#   [ ] cess_esp............ CESS-ESP Treebank
#   [ ] chat80.............. Chat-80 Data Files
#   [ ] city_database....... City Database
#   [ ] cmudict............. The Carnegie Mellon Pronouncing Dictionary (0.6)
#   [ ] comparative_sentences Comparative Sentence Dataset
#   [ ] comtrans............ ComTrans Corpus Sample
#   [ ] conll2000........... CONLL 2000 Chunking Corpus
#   [ ] conll2002........... CONLL 2002 Named Entity Recognition Corpus
# Hit Enter to continue:
#   [ ] conll2007........... Dependency Treebanks from CoNLL 2007 (Catalan
#                            and Basque Subset)
#   [ ] crubadan............ Crubadan Corpus
#   [ ] dependency_treebank. Dependency Parsed Treebank
#   [ ] dolch............... Dolch Word List
#   [ ] europarl_raw........ Sample European Parliament Proceedings Parallel
#                            Corpus
#   [ ] extended_omw........ Extended Open Multilingual WordNet
#   [ ] floresta............ Portuguese Treebank
#   [ ] framenet_v15........ FrameNet 1.5
#   [ ] framenet_v17........ FrameNet 1.7
#   [ ] gazetteers.......... Gazeteer Lists
#   [ ] genesis............. Genesis Corpus
#   [ ] gutenberg........... Project Gutenberg Selections
#   [ ] ieer................ NIST IE-ER DATA SAMPLE
#   [ ] inaugural........... C-Span Inaugural Address Corpus
#   [ ] indian.............. Indian Language POS-Tagged Corpus
#   [ ] jeita............... JEITA Public Morphologically Tagged Corpus (in
#                            ChaSen format)
#   [ ] kimmo............... PC-KIMMO Data Files
#   [ ] knbc................ KNB Corpus (Annotated blog corpus)
# Hit Enter to continue:
#   [ ] large_grammars...... Large context-free and feature-based grammars
#                            for parser comparison
#   [ ] lin_thesaurus....... Lin's Dependency Thesaurus
#   [ ] mac_morpho.......... MAC-MORPHO: Brazilian Portuguese news text with
#                            part-of-speech tags
#   [ ] machado............. Machado de Assis -- Obra Completa
#   [ ] masc_tagged......... MASC Tagged Corpus
#   [ ] maxent_ne_chunker... ACE Named Entity Chunker (Maximum entropy)
#   [ ] maxent_treebank_pos_tagger Treebank Part of Speech Tagger (Maximum entropy)
#   [ ] moses_sample........ Moses Sample Models
#   [ ] movie_reviews....... Sentiment Polarity Dataset Version 2.0
#   [ ] mte_teip5........... MULTEXT-East 1984 annotated corpus 4.0
#   [ ] mwa_ppdb............ The monolingual word aligner (Sultan et al.
#                            2015) subset of the Paraphrase Database.
#   [ ] names............... Names Corpus, Version 1.3 (1994-03-29)
#   [ ] nombank.1.0......... NomBank Corpus 1.0
#   [ ] nonbreaking_prefixes Non-Breaking Prefixes (Moses Decoder)
#   [ ] nps_chat............ NPS Chat
#   [ ] omw-1.4............. Open Multilingual Wordnet
#   [ ] omw................. Open Multilingual Wordnet
#   [ ] opinion_lexicon..... Opinion Lexicon
# Hit Enter to continue:
#   [ ] panlex_swadesh...... PanLex Swadesh Corpora
#   [ ] paradigms........... Paradigm Corpus
#   [ ] pe08................ Cross-Framework and Cross-Domain Parser
#                            Evaluation Shared Task
#   [ ] perluniprops........ perluniprops: Index of Unicode Version 7.0.0
#                            character properties in Perl
#   [ ] pil................. The Patient Information Leaflet (PIL) Corpus
#   [ ] pl196x.............. Polish language of the XX century sixties
#   [ ] porter_test......... Porter Stemmer Test Files
#   [ ] ppattach............ Prepositional Phrase Attachment Corpus
#   [ ] problem_reports..... Problem Report Corpus
#   [ ] product_reviews_1... Product Reviews (5 Products)
#   [ ] product_reviews_2... Product Reviews (9 Products)
#   [ ] propbank............ Proposition Bank Corpus 1.0
#   [ ] pros_cons........... Pros and Cons
#   [ ] ptb................. Penn Treebank
#   [ ] punkt............... Punkt Tokenizer Models
#   [ ] qc.................. Experimental Data for Question Classification
#   [ ] reuters............. The Reuters-21578 benchmark corpus, ApteMod
#                            version
#   [ ] rslp................ RSLP Stemmer (Removedor de Sufixos da Lingua
#                            Portuguesa)
# Hit Enter to continue:
#   [ ] rte................. PASCAL RTE Challenges 1, 2, and 3
#   [ ] sample_grammars..... Sample Grammars
#   [ ] semcor.............. SemCor 3.0
#   [ ] senseval............ SENSEVAL 2 Corpus: Sense Tagged Text
#   [ ] sentence_polarity... Sentence Polarity Dataset v1.0
#   [ ] sentiwordnet........ SentiWordNet
#   [ ] shakespeare......... Shakespeare XML Corpus Sample
#   [ ] sinica_treebank..... Sinica Treebank Corpus Sample
#   [ ] smultron............ SMULTRON Corpus Sample
#   [ ] snowball_data....... Snowball Data
#   [ ] spanish_grammars.... Grammars for Spanish
#   [ ] state_union......... C-Span State of the Union Address Corpus
#   [ ] stopwords........... Stopwords Corpus
#   [ ] subjectivity........ Subjectivity Dataset v1.0
#   [ ] swadesh............. Swadesh Wordlists
#   [ ] switchboard......... Switchboard Corpus Sample
#   [ ] tagsets............. Help on Tagsets
#   [ ] timit............... TIMIT Corpus Sample
#   [ ] toolbox............. Toolbox Sample Files
#   [ ] treebank............ Penn Treebank Sample
#   [ ] twitter_samples..... Twitter Samples
# Hit Enter to continue:
#   [ ] udhr2............... Universal Declaration of Human Rights Corpus
#                            (Unicode Version)
#   [ ] udhr................ Universal Declaration of Human Rights Corpus
#   [ ] unicode_samples..... Unicode Samples
#   [ ] universal_tagset.... Mappings to the Universal Part-of-Speech Tagset
#   [ ] universal_treebanks_v20 Universal Treebanks Version 2.0
#   [ ] vader_lexicon....... VADER Sentiment Lexicon
#   [ ] verbnet3............ VerbNet Lexicon, Version 3.3
#   [ ] verbnet............. VerbNet Lexicon, Version 2.1
#   [ ] webtext............. Web Text Corpus
#   [ ] wmt15_eval.......... Evaluation data from WMT15
#   [ ] word2vec_sample..... Word2Vec Sample
#   [ ] wordnet2021......... Open English Wordnet 2021
#   [ ] wordnet31........... Wordnet 3.1
#   [ ] wordnet............. WordNet
#   [ ] wordnet_ic.......... WordNet-InfoContent
#   [ ] words............... Word Lists
#   [ ] ycoe................ York-Toronto-Helsinki Parsed Corpus of Old
#                            English Prose
#
# Collections:
#   [ ] all-corpora......... All the corpora
# Hit Enter to continue:
#   [ ] all-nltk............ All packages available on nltk_data gh-pages
#                            branch
#   [ ] all................. All packages
#   [ ] book................ Everything used in the NLTK Book
#   [ ] popular............. Popular packages
#   [ ] tests............... Packages for running tests
#   [ ] third-party......... Third-party data packages
#
# ([*] marks installed packages)
#
# Download which package (l=list; x=cancel)?
#   Identifier>
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> l
# Packages:
#   [ ] abc................. Australian Broadcasting Commission 2006
#   [ ] alpino.............. Alpino Dutch Treebank
#   [ ] averaged_perceptron_tagger Averaged Perceptron Tagger
#   [ ] averaged_perceptron_tagger_ru Averaged Perceptron Tagger (Russian)
#   [ ] basque_grammars..... Grammars for Basque
#   [ ] biocreative_ppi..... BioCreAtIvE (Critical Assessment of Information
#                            Extraction Systems in Biology)
#   [ ] bllip_wsj_no_aux.... BLLIP Parser: WSJ Model
#   [ ] book_grammars....... Grammars from NLTK Book
#   [ ] brown............... Brown Corpus
#   [ ] brown_tei........... Brown Corpus (TEI XML Version)
#   [ ] cess_cat............ CESS-CAT Treebank
#   [ ] cess_esp............ CESS-ESP Treebank
#   [ ] chat80.............. Chat-80 Data Files
#   [ ] city_database....... City Database
#   [ ] cmudict............. The Carnegie Mellon Pronouncing Dictionary (0.6)
#   [ ] comparative_sentences Comparative Sentence Dataset
#   [ ] comtrans............ ComTrans Corpus Sample
#   [ ] conll2000........... CONLL 2000 Chunking Corpus
#   [ ] conll2002........... CONLL 2002 Named Entity Recognition Corpus
# Hit Enter to continue:
#   [ ] conll2007........... Dependency Treebanks from CoNLL 2007 (Catalan
#                            and Basque Subset)
#   [ ] crubadan............ Crubadan Corpus
#   [ ] dependency_treebank. Dependency Parsed Treebank
#   [ ] dolch............... Dolch Word List
#   [ ] europarl_raw........ Sample European Parliament Proceedings Parallel
#                            Corpus
#   [ ] extended_omw........ Extended Open Multilingual WordNet
#   [ ] floresta............ Portuguese Treebank
#   [ ] framenet_v15........ FrameNet 1.5
#   [ ] framenet_v17........ FrameNet 1.7
#   [ ] gazetteers.......... Gazeteer Lists
#   [ ] genesis............. Genesis Corpus
#   [ ] gutenberg........... Project Gutenberg Selections
#   [ ] ieer................ NIST IE-ER DATA SAMPLE
#   [ ] inaugural........... C-Span Inaugural Address Corpus
#   [ ] indian.............. Indian Language POS-Tagged Corpus
#   [ ] jeita............... JEITA Public Morphologically Tagged Corpus (in
#                            ChaSen format)
#   [ ] kimmo............... PC-KIMMO Data Files
#   [ ] knbc................ KNB Corpus (Annotated blog corpus)
# Hit Enter to continue:
#   [ ] large_grammars...... Large context-free and feature-based grammars
#                            for parser comparison
#   [ ] lin_thesaurus....... Lin's Dependency Thesaurus
#   [ ] mac_morpho.......... MAC-MORPHO: Brazilian Portuguese news text with
#                            part-of-speech tags
#   [ ] machado............. Machado de Assis -- Obra Completa
#   [ ] masc_tagged......... MASC Tagged Corpus
#   [ ] maxent_ne_chunker... ACE Named Entity Chunker (Maximum entropy)
#   [ ] maxent_treebank_pos_tagger Treebank Part of Speech Tagger (Maximum entropy)
#   [ ] moses_sample........ Moses Sample Models
#   [ ] movie_reviews....... Sentiment Polarity Dataset Version 2.0
#   [ ] mte_teip5........... MULTEXT-East 1984 annotated corpus 4.0
#   [ ] mwa_ppdb............ The monolingual word aligner (Sultan et al.
#                            2015) subset of the Paraphrase Database.
#   [ ] names............... Names Corpus, Version 1.3 (1994-03-29)
#   [ ] nombank.1.0......... NomBank Corpus 1.0
#   [ ] nonbreaking_prefixes Non-Breaking Prefixes (Moses Decoder)
#   [ ] nps_chat............ NPS Chat
#   [ ] omw-1.4............. Open Multilingual Wordnet
#   [ ] omw................. Open Multilingual Wordnet
#   [ ] opinion_lexicon..... Opinion Lexicon
# Hit Enter to continue:
#   [ ] panlex_swadesh...... PanLex Swadesh Corpora
#   [ ] paradigms........... Paradigm Corpus
#   [ ] pe08................ Cross-Framework and Cross-Domain Parser
#                            Evaluation Shared Task
#   [ ] perluniprops........ perluniprops: Index of Unicode Version 7.0.0
#                            character properties in Perl
#   [ ] pil................. The Patient Information Leaflet (PIL) Corpus
#   [ ] pl196x.............. Polish language of the XX century sixties
#   [ ] porter_test......... Porter Stemmer Test Files
#   [ ] ppattach............ Prepositional Phrase Attachment Corpus
#   [ ] problem_reports..... Problem Report Corpus
#   [ ] product_reviews_1... Product Reviews (5 Products)
#   [ ] product_reviews_2... Product Reviews (9 Products)
#   [ ] propbank............ Proposition Bank Corpus 1.0
#   [ ] pros_cons........... Pros and Cons
#   [ ] ptb................. Penn Treebank
#   [ ] punkt............... Punkt Tokenizer Models
#   [ ] qc.................. Experimental Data for Question Classification
#   [ ] reuters............. The Reuters-21578 benchmark corpus, ApteMod
#                            version
#   [ ] rslp................ RSLP Stemmer (Removedor de Sufixos da Lingua
#                            Portuguesa)
# Hit Enter to continue:
#   [ ] rte................. PASCAL RTE Challenges 1, 2, and 3
#   [ ] sample_grammars..... Sample Grammars
#   [ ] semcor.............. SemCor 3.0
#   [ ] senseval............ SENSEVAL 2 Corpus: Sense Tagged Text
#   [ ] sentence_polarity... Sentence Polarity Dataset v1.0
#   [ ] sentiwordnet........ SentiWordNet
#   [ ] shakespeare......... Shakespeare XML Corpus Sample
#   [ ] sinica_treebank..... Sinica Treebank Corpus Sample
#   [ ] smultron............ SMULTRON Corpus Sample
#   [ ] snowball_data....... Snowball Data
#   [ ] spanish_grammars.... Grammars for Spanish
#   [ ] state_union......... C-Span State of the Union Address Corpus
#   [ ] stopwords........... Stopwords Corpus
#   [ ] subjectivity........ Subjectivity Dataset v1.0
#   [ ] swadesh............. Swadesh Wordlists
#   [ ] switchboard......... Switchboard Corpus Sample
#   [ ] tagsets............. Help on Tagsets
#   [ ] timit............... TIMIT Corpus Sample
#   [ ] toolbox............. Toolbox Sample Files
#   [ ] treebank............ Penn Treebank Sample
#   [ ] twitter_samples..... Twitter Samples
# Hit Enter to continue:
#   [ ] udhr2............... Universal Declaration of Human Rights Corpus
#                            (Unicode Version)
#   [ ] udhr................ Universal Declaration of Human Rights Corpus
#   [ ] unicode_samples..... Unicode Samples
#   [ ] universal_tagset.... Mappings to the Universal Part-of-Speech Tagset
#   [ ] universal_treebanks_v20 Universal Treebanks Version 2.0
#   [ ] vader_lexicon....... VADER Sentiment Lexicon
#   [ ] verbnet3............ VerbNet Lexicon, Version 3.3
#   [ ] verbnet............. VerbNet Lexicon, Version 2.1
#   [ ] webtext............. Web Text Corpus
#   [ ] wmt15_eval.......... Evaluation data from WMT15
#   [ ] word2vec_sample..... Word2Vec Sample
#   [ ] wordnet2021......... Open English Wordnet 2021
#   [ ] wordnet31........... Wordnet 3.1
#   [ ] wordnet............. WordNet
#   [ ] wordnet_ic.......... WordNet-InfoContent
#   [ ] words............... Word Lists
#   [ ] ycoe................ York-Toronto-Helsinki Parsed Corpus of Old
#                            English Prose
#
# Collections:
#   [ ] all-corpora......... All the corpora
# Hit Enter to continue:
#   [ ] all-nltk............ All packages available on nltk_data gh-pages
#                            branch
#   [ ] all................. All packages
#   [ ] book................ Everything used in the NLTK Book
#   [ ] popular............. Popular packages
#   [ ] tests............... Packages for running tests
#   [ ] third-party......... Third-party data packages
#
# ([*] marks installed packages)
#
# Download which package (l=list; x=cancel)?
#   Identifier> l
# Packages:
#   [ ] abc................. Australian Broadcasting Commission 2006
#   [ ] alpino.............. Alpino Dutch Treebank
#   [ ] averaged_perceptron_tagger Averaged Perceptron Tagger
#   [ ] averaged_perceptron_tagger_ru Averaged Perceptron Tagger (Russian)
#   [ ] basque_grammars..... Grammars for Basque
#   [ ] biocreative_ppi..... BioCreAtIvE (Critical Assessment of Information
#                            Extraction Systems in Biology)
#   [ ] bllip_wsj_no_aux.... BLLIP Parser: WSJ Model
#   [ ] book_grammars....... Grammars from NLTK Book
#   [ ] brown............... Brown Corpus
#   [ ] brown_tei........... Brown Corpus (TEI XML Version)
#   [ ] cess_cat............ CESS-CAT Treebank
#   [ ] cess_esp............ CESS-ESP Treebank
#   [ ] chat80.............. Chat-80 Data Files
#   [ ] city_database....... City Database
#   [ ] cmudict............. The Carnegie Mellon Pronouncing Dictionary (0.6)
#   [ ] comparative_sentences Comparative Sentence Dataset
#   [ ] comtrans............ ComTrans Corpus Sample
#   [ ] conll2000........... CONLL 2000 Chunking Corpus
#   [ ] conll2002........... CONLL 2002 Named Entity Recognition Corpus
# Hit Enter to continue:
#   [ ] conll2007........... Dependency Treebanks from CoNLL 2007 (Catalan
#                            and Basque Subset)
#   [ ] crubadan............ Crubadan Corpus
#   [ ] dependency_treebank. Dependency Parsed Treebank
#   [ ] dolch............... Dolch Word List
#   [ ] europarl_raw........ Sample European Parliament Proceedings Parallel
#                            Corpus
#   [ ] extended_omw........ Extended Open Multilingual WordNet
#   [ ] floresta............ Portuguese Treebank
#   [ ] framenet_v15........ FrameNet 1.5
#   [ ] framenet_v17........ FrameNet 1.7
#   [ ] gazetteers.......... Gazeteer Lists
#   [ ] genesis............. Genesis Corpus
#   [ ] gutenberg........... Project Gutenberg Selections
#   [ ] ieer................ NIST IE-ER DATA SAMPLE
#   [ ] inaugural........... C-Span Inaugural Address Corpus
#   [ ] indian.............. Indian Language POS-Tagged Corpus
#   [ ] jeita............... JEITA Public Morphologically Tagged Corpus (in
#                            ChaSen format)
#   [ ] kimmo............... PC-KIMMO Data Files
#   [ ] knbc................ KNB Corpus (Annotated blog corpus)
# Hit Enter to continue:
#   [ ] large_grammars...... Large context-free and feature-based grammars
#                            for parser comparison
#   [ ] lin_thesaurus....... Lin's Dependency Thesaurus
#   [ ] mac_morpho.......... MAC-MORPHO: Brazilian Portuguese news text with
#                            part-of-speech tags
#   [ ] machado............. Machado de Assis -- Obra Completa
#   [ ] masc_tagged......... MASC Tagged Corpus
#   [ ] maxent_ne_chunker... ACE Named Entity Chunker (Maximum entropy)
#   [ ] maxent_treebank_pos_tagger Treebank Part of Speech Tagger (Maximum entropy)
#   [ ] moses_sample........ Moses Sample Models
#   [ ] movie_reviews....... Sentiment Polarity Dataset Version 2.0
#   [ ] mte_teip5........... MULTEXT-East 1984 annotated corpus 4.0
#   [ ] mwa_ppdb............ The monolingual word aligner (Sultan et al.
#                            2015) subset of the Paraphrase Database.
#   [ ] names............... Names Corpus, Version 1.3 (1994-03-29)
#   [ ] nombank.1.0......... NomBank Corpus 1.0
#   [ ] nonbreaking_prefixes Non-Breaking Prefixes (Moses Decoder)
#   [ ] nps_chat............ NPS Chat
#   [ ] omw-1.4............. Open Multilingual Wordnet
#   [ ] omw................. Open Multilingual Wordnet
#   [ ] opinion_lexicon..... Opinion Lexicon
# Hit Enter to continue:
#   [ ] panlex_swadesh...... PanLex Swadesh Corpora
#   [ ] paradigms........... Paradigm Corpus
#   [ ] pe08................ Cross-Framework and Cross-Domain Parser
#                            Evaluation Shared Task
#   [ ] perluniprops........ perluniprops: Index of Unicode Version 7.0.0
#                            character properties in Perl
#   [ ] pil................. The Patient Information Leaflet (PIL) Corpus
#   [ ] pl196x.............. Polish language of the XX century sixties
#   [ ] porter_test......... Porter Stemmer Test Files
#   [ ] ppattach............ Prepositional Phrase Attachment Corpus
#   [ ] problem_reports..... Problem Report Corpus
#   [ ] product_reviews_1... Product Reviews (5 Products)
#   [ ] product_reviews_2... Product Reviews (9 Products)
#   [ ] propbank............ Proposition Bank Corpus 1.0
#   [ ] pros_cons........... Pros and Cons
#   [ ] ptb................. Penn Treebank
#   [ ] punkt............... Punkt Tokenizer Models
#   [ ] qc.................. Experimental Data for Question Classification
#   [ ] reuters............. The Reuters-21578 benchmark corpus, ApteMod
#                            version
#   [ ] rslp................ RSLP Stemmer (Removedor de Sufixos da Lingua
#                            Portuguesa)
# Hit Enter to continue:
#   [ ] rte................. PASCAL RTE Challenges 1, 2, and 3
#   [ ] sample_grammars..... Sample Grammars
#   [ ] semcor.............. SemCor 3.0
#   [ ] senseval............ SENSEVAL 2 Corpus: Sense Tagged Text
#   [ ] sentence_polarity... Sentence Polarity Dataset v1.0
#   [ ] sentiwordnet........ SentiWordNet
#   [ ] shakespeare......... Shakespeare XML Corpus Sample
#   [ ] sinica_treebank..... Sinica Treebank Corpus Sample
#   [ ] smultron............ SMULTRON Corpus Sample
#   [ ] snowball_data....... Snowball Data
#   [ ] spanish_grammars.... Grammars for Spanish
#   [ ] state_union......... C-Span State of the Union Address Corpus
#   [ ] stopwords........... Stopwords Corpus
#   [ ] subjectivity........ Subjectivity Dataset v1.0
#   [ ] swadesh............. Swadesh Wordlists
#   [ ] switchboard......... Switchboard Corpus Sample
#   [ ] tagsets............. Help on Tagsets
#   [ ] timit............... TIMIT Corpus Sample
#   [ ] toolbox............. Toolbox Sample Files
#   [ ] treebank............ Penn Treebank Sample
#   [ ] twitter_samples..... Twitter Samples
# Hit Enter to continue:
#   [ ] udhr2............... Universal Declaration of Human Rights Corpus
#                            (Unicode Version)
#   [ ] udhr................ Universal Declaration of Human Rights Corpus
#   [ ] unicode_samples..... Unicode Samples
#   [ ] universal_tagset.... Mappings to the Universal Part-of-Speech Tagset
#   [ ] universal_treebanks_v20 Universal Treebanks Version 2.0
#   [ ] vader_lexicon....... VADER Sentiment Lexicon
#   [ ] verbnet3............ VerbNet Lexicon, Version 3.3
#   [ ] verbnet............. VerbNet Lexicon, Version 2.1
#   [ ] webtext............. Web Text Corpus
#   [ ] wmt15_eval.......... Evaluation data from WMT15
#   [ ] word2vec_sample..... Word2Vec Sample
#   [ ] wordnet2021......... Open English Wordnet 2021
#   [ ] wordnet31........... Wordnet 3.1
#   [ ] wordnet............. WordNet
#   [ ] wordnet_ic.......... WordNet-InfoContent
#   [ ] words............... Word Lists
#   [ ] ycoe................ York-Toronto-Helsinki Parsed Corpus of Old
#                            English Prose
#
# Collections:
#   [ ] all-corpora......... All the corpora
# Hit Enter to continue:
#   [ ] all-nltk............ All packages available on nltk_data gh-pages
#                            branch
#   [ ] all................. All packages
#   [ ] book................ Everything used in the NLTK Book
#   [ ] popular............. Popular packages
#   [ ] tests............... Packages for running tests
#   [ ] third-party......... Third-party data packages
#
# ([*] marks installed packages)
#
# Download which package (l=list; x=cancel)?
#   Identifier>
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> c
#
# Data Server:
#   - URL: <https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml>
#   - 7 Package Collections Available
#   - 111 Individual Packages Available
#
# Local Machine:
#   - Data directory: /root/nltk_data
#
# ---------------------------------------------------------------------------
#     s) Show Config   u) Set Server URL   d) Set Data Dir   m) Main Menu
# ---------------------------------------------------------------------------
# Config> m
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %%
df['Lower Case'] = df['Review'].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %%
df['Removal of Punctuation'] = df['Lower Case'].str.replace('[^\w\s]','')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
import re
df['Removal of Special Characters'] = df['Removal of Punctuation'].apply(lambda x: ''.join(re.sub(r"[^a-zA-Z0-9]+", ' ', charctr) for charctr in x ))

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stop = stopwords.words('english')
df['Stopwords Removal'] = df['Removal of Punctuation'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
from textblob import TextBlob
df['Spelling Correction'] = df['Stopwords Removal'].apply(lambda x: str(TextBlob(x).correct()))

# %%
import nltk
nltk.download('punkt')
df['Tokenization'] = df['Spelling Correction'].apply(lambda x: TextBlob(x).words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk.stem import PorterStemmer
st = PorterStemmer()
df['After Stemming'] = df['Tokenization'].apply(lambda x: " ".join([st.stem(word) for word in x]))

# %%
from textblob import Word
import nltk
nltk.download('wordnet')

df['After Lemmatization'] = df['After Stemming'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
df.to_csv('/content/sample_data/reviwes.csv',index=False)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
import itertools
import collections
from nltk import ngrams
from nltk.tokenize import word_tokenize

words_sentence = []
for sentence in df['After Lemmatization']:
  words_sentence.append(word_tokenize(sentence))
aftercleaning = [x for x in words_sentence if x != []]
iterations = list(itertools.chain.from_iterable(aftercleaning))

# %%
tri_grams = nltk.trigrams(iterations)
frequency_dist = nltk.FreqDist(tri_grams)
frequency_dist
# Out:
# FreqDist({('everi', 'movi', 'come'): 1,
#           ('movi', 'come', 'truli'): 1,
#           ('come', 'truli', 'make'): 1,
#           ('truli', 'make', 'impact'): 1,
#           ('make', 'impact', 'joaquin'): 1,
#           ('impact', 'joaquin', 'perform'): 1,
#           ('joaquin', 'perform', 'scenographi'): 1,
#           ('perform', 'scenographi', 'brillianc'): 1,
#           ('scenographi', 'brillianc', 'grotesqu'): 1,
#           ('brillianc', 'grotesqu', 'hunt'): 1,
#           ('grotesqu', 'hunt', 'cring'): 1,
#           ('hunt', 'cring', 'hard'): 1,
#           ('cring', 'hard', 'watch'): 1,
#           ('hard', 'watch', 'time'): 1,
#           ('watch', 'time', 'mesmer'): 1,
#           ('time', 'mesmer', 'wont'): 1,
#           ('mesmer', 'wont', 'blink'): 1,
#           ('wont', 'blink', 'eye'): 1,
#           ('blink', 'eye', 'watch'): 1,
#           ('eye', 'watch', 'tragic'): 1,
#           ('watch', 'tragic', 'serious'): 1,
#           ('tragic', 'serious', 'funni'): 1,
#           ('serious', 'funni', 'moment'): 1,
#           ('funni', 'moment', 'emot'): 1,
#           ('moment', 'emot', 'rollercoast'): 1,
#           ('emot', 'rollercoast', 'sometim'): 1,
#           ('rollercoast', 'sometim', 'multipl'): 1,
#           ('sometim', 'multipl', 'emot'): 1,
#           ('multipl', 'emot', 'pop'): 1,
#           ('emot', 'pop', 'time'): 1,
#           ('pop', 'time', 'far'): 1,
#           ('time', 'far', 'typic'): 1,
#           ('far', 'typic', 'actionriddl'): 1,
#           ('typic', 'actionriddl', 'predict'): 1,
#           ('actionriddl', 'predict', 'superhero'): 1,
#           ('predict', 'superhero', 'movi'): 1,
#           ('superhero', 'movi', 'proper'): 1,
#           ('movi', 'proper', 'psycholog'): 1,
#           ('proper', 'psycholog', 'thrillerdrama'): 1,
#           ('psycholog', 'thrillerdrama', 'singl'): 1,
#           ('thrillerdrama', 'singl', 'best'): 1,
#           ('singl', 'best', 'charact'): 1,
#           ('best', 'charact', 'develop'): 1,
#           ('charact', 'develop', 'ever'): 1,
#           ('develop', 'ever', 'seen'): 1,
#           ('ever', 'seen', 'movi'): 2,
#           ('seen', 'movi', 'felt'): 1,
#           ('movi', 'felt', 'alon'): 1,
#           ('felt', 'alon', 'isol'): 1,
#           ('alon', 'isol', 'truli'): 1,
#           ('isol', 'truli', 'relat'): 1,
#           ('truli', 'relat', 'understand'): 1,
#           ('relat', 'understand', 'motiv'): 1,
#           ('understand', 'motiv', 'feel'): 1,
#           ('motiv', 'feel', 'sorri'): 1,
#           ('feel', 'sorri', 'charact'): 1,
#           ('sorri', 'charact', 'lot'): 1,
#           ('charact', 'lot', 'peopl'): 1,
#           ('lot', 'peopl', 'see'): 1,
#           ('peopl', 'see', 'movi'): 1,
#           ('see', 'movi', 'think'): 1,
#           ('movi', 'think', 'encourag'): 1,
#           ('think', 'encourag', 'violenc'): 1,
#           ('encourag', 'violenc', 'truli'): 1,
#           ('violenc', 'truli', 'movi'): 1,
#           ('truli', 'movi', 'encourag'): 1,
#           ('movi', 'encourag', 'everi'): 1,
#           ('encourag', 'everi', 'one'): 1,
#           ('everi', 'one', 'u'): 1,
#           ('one', 'u', 'becom'): 1,
#           ('u', 'becom', 'better'): 1,
#           ('becom', 'better', 'person'): 1,
#           ('better', 'person', 'treat'): 1,
#           ('person', 'treat', 'everyon'): 1,
#           ('treat', 'everyon', 'respect'): 1,
#           ('everyon', 'respect', 'make'): 1,
#           ('respect', 'make', 'feel'): 1,
#           ('make', 'feel', 'like'): 1,
#           ('feel', 'like', 'belong'): 1,
#           ('like', 'belong', 'world'): 1,
#           ('belong', 'world', 'instead'): 1,
#           ('world', 'instead', 'make'): 1,
#           ('instead', 'make', 'feel'): 1,
#           ('make', 'feel', 'isol'): 1,
#           ('feel', 'isol', 'truli'): 1,
#           ('isol', 'truli', 'masterpiec'): 1,
#           ('truli', 'masterpiec', 'best'): 1,
#           ('masterpiec', 'best', 'hollywood'): 1,
#           ('best', 'hollywood', 'film'): 1,
#           ('hollywood', 'film', '2019'): 1,
#           ('film', '2019', 'one'): 1,
#           ('2019', 'one', 'best'): 1,
#           ('one', 'best', 'film'): 1,
#           ('best', 'film', 'decad'): 1,
#           ('film', 'decad', 'truli'): 1,
#           ('decad', 'truli', 'best'): 1,
#           ('truli', 'best', 'film'): 1,
#           ('best', 'film', 'bring'): 1,
#           ('film', 'bring', 'comic'): 1,
#           ('bring', 'comic', 'book'): 1,
#           ('comic', 'book', 'willingli'): 1,
#           ('book', 'willingli', 'realist'): 1,
#           ('willingli', 'realist', 'real'): 1,
#           ('realist', 'real', 'if'): 1,
#           ('real', 'if', 'remark'): 1,
#           ('if', 'remark', 'direct'): 1,
#           ('remark', 'direct', 'cinematographi'): 1,
#           ('direct', 'cinematographi', 'music'): 1,
#           ('cinematographi', 'music', 'act'): 1,
#           ('music', 'act', 'peopl'): 1,
#           ('act', 'peopl', 'surpris'): 1,
#           ('peopl', 'surpris', 'find'): 1,
#           ('surpris', 'find', 'disturb'): 1,
#           ('find', 'disturb', 'violent'): 1,
#           ('disturb', 'violent', 'necess'): 1,
#           ('violent', 'necess', 'messag'): 1,
#           ('necess', 'messag', 'societi'): 1,
#           ('messag', 'societi', 'reflect'): 1,
#           ('societi', 'reflect', 'underappreciatedunrecognizedbulli'): 1,
#           ('reflect', 'underappreciatedunrecognizedbulli', 'peopl'): 1,
#           ('underappreciatedunrecognizedbulli', 'peopl', 'prove'): 1,
#           ('peopl', 'prove', 'someth'): 1,
#           ('prove', 'someth', 'way'): 1,
#           ('someth', 'way', 'show'): 1,
#           ('way', 'show', 'class'): 1,
#           ('show', 'class', 'differ'): 1,
#           ('class', 'differ', 'corrupt'): 1,
#           ('differ', 'corrupt', 'rich'): 1,
#           ('corrupt', 'rich', 'talent'): 1,
#           ('rich', 'talent', 'rule'): 1,
#           ('talent', 'rule', 'other'): 1,
#           ('rule', 'other', 'around'): 1,
#           ('other', 'around', 'exagger'): 1,
#           ('around', 'exagger', 'that'): 1,
#           ('exagger', 'that', 'make'): 1,
#           ('that', 'make', 'differ'): 1,
#           ('make', 'differ', 'believ'): 1,
#           ('differ', 'believ', 'could'): 1,
#           ('believ', 'could', 'multipl'): 1,
#           ('could', 'multipl', 'joke'): 1,
#           ('multipl', 'joke', 'live'): 1,
#           ('joke', 'live', 'societi'): 1,
#           ('live', 'societi', 'could'): 1,
#           ('societi', 'could', 'shake'): 1,
#           ('could', 'shake', 'around'): 1,
#           ('shake', 'around', 'much'): 1,
#           ('around', 'much', 'bitter'): 1,
#           ('much', 'bitter', 'way'): 1,
#           ('bitter', 'way', 'film'): 1,
#           ('way', 'film', 'show'): 1,
#           ('film', 'show', 'make'): 1,
#           ('show', 'make', 'peopl'): 1,
#           ('make', 'peopl', 'comfort'): 1,
#           ('peopl', 'comfort', 'peopl'): 1,
#           ('comfort', 'peopl', 'consid'): 1,
#           ('peopl', 'consid', 'wake'): 1,
#           ('consid', 'wake', 'call'): 1,
#           ('wake', 'call', 'messag'): 1,
#           ('call', 'messag', 'first'): 1,
#           ('messag', 'first', 'film'): 1,
#           ('first', 'film', 'perfect'): 1,
#           ('film', 'perfect', 'film'): 1,
#           ('perfect', 'film', 'joaquin'): 1,
#           ('film', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'give'): 3,
#           ('phoenix', 'give', 'tour'): 1,
#           ('give', 'tour', 'de'): 1,
#           ('tour', 'de', 'forc'): 1,
#           ('de', 'forc', 'perform'): 1,
#           ('forc', 'perform', 'fearless'): 1,
#           ('perform', 'fearless', 'stun'): 1,
#           ('fearless', 'stun', 'emot'): 1,
#           ('stun', 'emot', 'depth'): 1,
#           ('emot', 'depth', 'physic'): 1,
#           ('depth', 'physic', 'imposs'): 1,
#           ('physic', 'imposs', 'talk'): 1,
#           ('imposs', 'talk', 'without'): 1,
#           ('talk', 'without', 'referenc'): 1,
#           ('without', 'referenc', 'heath'): 1,
#           ('referenc', 'heath', 'ledger'): 1,
#           ('heath', 'ledger', 'oscarwin'): 1,
#           ('ledger', 'oscarwin', 'perform'): 1,
#           ('oscarwin', 'perform', 'dark'): 1,
#           ('perform', 'dark', 'knight'): 1,
#           ('dark', 'knight', 'wide'): 1,
#           ('knight', 'wide', 'consid'): 1,
#           ('wide', 'consid', 'definit'): 1,
#           ('consid', 'definit', 'liveact'): 1,
#           ('definit', 'liveact', 'portray'): 1,
#           ('liveact', 'portray', 'joke'): 1,
#           ('portray', 'joke', 'let'): 1,
#           ('joke', 'let', 'talk'): 1,
#           ('let', 'talk', 'fact'): 1,
#           ('talk', 'fact', 'everyon'): 1,
#           ('fact', 'everyon', 'go'): 1,
#           ('everyon', 'go', 'stun'): 1,
#           ('go', 'stun', 'phoenix'): 1,
#           ('stun', 'phoenix', 'accomplish'): 1,
#           ('phoenix', 'accomplish', 'mani'): 1,
#           ('accomplish', 'mani', 'thought'): 1,
#           ('mani', 'thought', 'imposs'): 1,
#           ('thought', 'imposs', 'portray'): 1,
#           ('imposs', 'portray', 'match'): 1,
#           ('portray', 'match', 'potenti'): 1,
#           ('match', 'potenti', 'exce'): 1,
#           ('potenti', 'exce', 'dark'): 1,
#           ('exce', 'dark', 'knight'): 1,
#           ('dark', 'knight', 'clown'): 1,
#           ('knight', 'clown', 'princ'): 1,
#           ('clown', 'princ', 'crime'): 1,
#           ('princ', 'crime', 'time'): 1,
#           ('crime', 'time', 'move'): 1,
#           ('time', 'move', 'anticip'): 1,
#           ('move', 'anticip', 'like'): 1,
#           ('anticip', 'like', 'end'): 1,
#           ('like', 'end', 'fall'): 1,
#           ('end', 'fall', 'short'): 1,
#           ('fall', 'short', 'way'): 1,
#           ('short', 'way', 'short'): 1,
#           ('way', 'short', 'joke'): 1,
#           ('short', 'joke', 'first'): 1,
#           ('joke', 'first', 'time'): 2,
#           ('first', 'time', 'happi'): 1,
#           ('time', 'happi', 'hope'): 1,
#           ('happi', 'hope', 'plea'): 1,
#           ('hope', 'plea', 'ignor'): 1,
#           ('plea', 'ignor', 'complaint'): 1,
#           ('ignor', 'complaint', 'pernici'): 1,
#           ('complaint', 'pernici', 'violenc'): 1,
#           ('pernici', 'violenc', 'embarrass'): 1,
#           ('violenc', 'embarrass', 'say'): 1,
#           ('embarrass', 'say', 'least'): 1,
#           ('say', 'least', 'haven'): 1,
#           ('least', 'haven', 'seen'): 1,
#           ('haven', 'seen', 'comic'): 1,
#           ('seen', 'comic', 'movi'): 1,
#           ('comic', 'movi', 'real'): 1,
#           ('movi', 'real', 'ever'): 1,
#           ('real', 'ever', 'deserv'): 1,
#           ('ever', 'deserv', 'better'): 1,
#           ('deserv', 'better', 'class'): 1,
#           ('better', 'class', 'crimin'): 1,
#           ('class', 'crimin', 'phillip'): 1,
#           ('crimin', 'phillip', 'phoenix'): 1,
#           ('phillip', 'phoenix', 'deliv'): 1,
#           ('phoenix', 'deliv', 'dark'): 1,
#           ('deliv', 'dark', 'joke'): 1,
#           ('dark', 'joke', 'dark'): 1,
#           ('joke', 'dark', 'fall'): 1,
#           ('dark', 'fall', 'love'): 1,
#           ('fall', 'love', 'villain'): 1,
#           ('love', 'villain', 'bad'): 1,
#           ('villain', 'bad', 'gun'): 1,
#           ('bad', 'gun', 'alway'): 1,
#           ('gun', 'alway', 'romant'): 1,
#           ('alway', 'romant', 'anyway'): 1,
#           ('romant', 'anyway', 'let'): 1,
#           ('anyway', 'let', 'start'): 1,
#           ('let', 'start', 'say'): 1,
#           ('start', 'say', 'joaquin'): 1,
#           ('say', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'doesn'): 2,
#           ('phoenix', 'doesn', 'get'): 1,
#           ('doesn', 'get', 'oscar'): 1,
#           ('get', 'oscar', 'movi'): 1,
#           ('oscar', 'movi', 'scar'): 1,
#           ('movi', 'scar', 'cancel'): 1,
#           ('scar', 'cancel', 'phoenix'): 1,
#           ('cancel', 'phoenix', 'amaz'): 1,
#           ('phoenix', 'amaz', 'might'): 1,
#           ('amaz', 'might', 'heard'): 1,
#           ('might', 'heard', 'everi'): 1,
#           ('heard', 'everi', 'review'): 1,
#           ('everi', 'review', 'ever'): 1,
#           ('review', 'ever', 'told'): 1,
#           ('ever', 'told', 'phillip'): 1,
#           ('told', 'phillip', 'best'): 1,
#           ('phillip', 'best', 'stori'): 1,
#           ('best', 'stori', 'line'): 1,
#           ('stori', 'line', 'take'): 1,
#           ('line', 'take', 'visual'): 1,
#           ('take', 'visual', 'breathtak'): 1,
#           ('visual', 'breathtak', 'score'): 1,
#           ('breathtak', 'score', 'org'): 1,
#           ('score', 'org', 'score'): 1,
#           ('org', 'score', 'everi'): 1,
#           ('score', 'everi', 'time'): 1,
#           ('everi', 'time', 'score'): 1,
#           ('time', 'score', 'came'): 1,
#           ('score', 'came', 'felt'): 1,
#           ('came', 'felt', 'uncomfort'): 1,
#           ('felt', 'uncomfort', 'like'): 1,
#           ('uncomfort', 'like', 'someth'): 1,
#           ('like', 'someth', 'horribl'): 1,
#           ('someth', 'horribl', 'happen'): 1,
#           ('horribl', 'happen', 'great'): 1,
#           ('happen', 'great', 'inspir'): 1,
#           ('great', 'inspir', 'taxi'): 1,
#           ('inspir', 'taxi', 'driver'): 2,
#           ('taxi', 'driver', 'king'): 4,
#           ('driver', 'king', 'comedi'): 4,
#           ('king', 'comedi', 'add'): 1,
#           ('comedi', 'add', 'much'): 1,
#           ('add', 'much', 'movi'): 1,
#           ('much', 'movi', 'got'): 1,
#           ('movi', 'got', 'honest'): 1,
#           ('got', 'honest', 'scene'): 1,
#           ('honest', 'scene', 'violent'): 1,
#           ('scene', 'violent', 'disturb'): 1,
#           ('violent', 'disturb', 'honestli'): 1,
#           ('disturb', 'honestli', 'expect'): 1,
#           ('honestli', 'expect', 'wayyyi'): 1,
#           ('expect', 'wayyyi', 'violent'): 1,
#           ('wayyyi', 'violent', 'controversi'): 1,
#           ('violent', 'controversi', 'go'): 1,
#           ('controversi', 'go', 'overal'): 1,
#           ('go', 'overal', 'movi'): 1,
#           ('overal', 'movi', 'great'): 1,
#           ('movi', 'great', 'come'): 1,
#           ('great', 'come', 'oscar'): 1,
#           ('come', 'oscar', 'season'): 1,
#           ('oscar', 'season', 'need'): 1,
#           ('season', 'need', 'nomin'): 1,
#           ('need', 'nomin', 'best'): 1,
#           ('nomin', 'best', 'pictur'): 1,
#           ('best', 'pictur', 'screenplay'): 1,
#           ('pictur', 'screenplay', 'cinematographi'): 1,
#           ('screenplay', 'cinematographi', 'actor'): 1,
#           ('cinematographi', 'actor', 'score'): 1,
#           ('actor', 'score', 'director'): 1,
#           ('score', 'director', 'get'): 1,
#           ('director', 'get', 'peopl'): 1,
#           ('get', 'peopl', 'hate'): 1,
#           ('peopl', 'hate', 'polit'): 1,
#           ('hate', 'polit', 'messag'): 1,
#           ('polit', 'messag', 'peopl'): 1,
#           ('messag', 'peopl', 'think'): 1,
#           ('peopl', 'think', 'need'): 1,
#           ('think', 'need', 'get'): 1,
#           ('need', 'get', 'empti'): 1,
#           ('get', 'empti', 'arthur'): 1,
#           ('empti', 'arthur', 'mad'): 1,
#           ('arthur', 'mad', 'come'): 1,
#           ('mad', 'come', 'point'): 1,
#           ('come', 'point', 'never'): 1,
#           ('point', 'never', 'enjoy'): 1,
#           ('never', 'enjoy', 'masterpiec'): 1,
#           ('enjoy', 'masterpiec', 'joaquin'): 1,
#           ('masterpiec', 'joaquin', 'phoenix'): 2,
#           ('joaquin', 'phoenix', 'told'): 1,
#           ('phoenix', 'told', 'phillip'): 1,
#           ('told', 'phillip', 'overdid'): 1,
#           ('phillip', 'overdid', 'movi'): 1,
#           ('overdid', 'movi', 'actingmus'): 1,
#           ('movi', 'actingmus', 'cinematographi'): 1,
#           ('actingmus', 'cinematographi', 'amaz'): 1,
#           ('cinematographi', 'amaz', 'plea'): 1,
#           ('amaz', 'plea', 'enjoy'): 1,
#           ('plea', 'enjoy', 'movi'): 1,
#           ('enjoy', 'movi', 'without'): 1,
#           ('movi', 'without', 'overthink'): 1,
#           ('without', 'overthink', 'seen'): 1,
#           ('overthink', 'seen', 'joke'): 1,
#           ('seen', 'joke', 'yesterday'): 1,
#           ('joke', 'yesterday', 'venic'): 1,
#           ('yesterday', 'venic', 'earli'): 1,
#           ('venic', 'earli', 'inflat'): 1,
#           ('earli', 'inflat', 'screen'): 1,
#           ('inflat', 'screen', 'troubl'): 1,
#           ('screen', 'troubl', 'audit'): 1,
#           ('troubl', 'audit', 'lead'): 1,
#           ('audit', 'lead', 'nearhour'): 1,
#           ('lead', 'nearhour', 'delay'): 1,
#           ('nearhour', 'delay', 'definit'): 1,
#           ('delay', 'definit', 'worth'): 1,
#           ('definit', 'worth', 'joke'): 1,
#           ('worth', 'joke', 'deserv'): 1,
#           ('joke', 'deserv', 'present'): 1,
#           ('deserv', 'present', 'venic'): 1,
#           ('present', 'venic', 'film'): 1,
#           ('venic', 'film', 'festiv'): 1,
#           ('film', 'festiv', 'event'): 1,
#           ('festiv', 'event', 'regard'): 1,
#           ('event', 'regard', 'cinema'): 1,
#           ('regard', 'cinema', 'form'): 1,
#           ('cinema', 'form', 'art'): 1,
#           ('form', 'art', 'film'): 1,
#           ('art', 'film', 'far'): 1,
#           ('film', 'far', 'blockbust'): 1,
#           ('far', 'blockbust', 'mere'): 1,
#           ('blockbust', 'mere', 'entertain'): 1,
#           ('mere', 'entertain', 'movi'): 1,
#           ('entertain', 'movi', 'film'): 1,
#           ('movi', 'film', 'gene'): 1,
#           ('film', 'gene', 'focus'): 1,
#           ('gene', 'focus', 'psychic'): 1,
#           ('focus', 'psychic', 'main'): 1,
#           ('psychic', 'main', 'charact'): 1,
#           ('main', 'charact', 'slowli'): 1,
#           ('charact', 'slowli', 'crumbl'): 1,
#           ('slowli', 'crumbl', 'pressur'): 1,
#           ('crumbl', 'pressur', 'societi'): 1,
#           ('pressur', 'societi', 'thu'): 1,
#           ('societi', 'thu', 'joaquin'): 1,
#           ('thu', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'wonder'): 1,
#           ('phoenix', 'wonder', 'perform'): 1,
#           ('wonder', 'perform', 'earn'): 1,
#           ('perform', 'earn', 'almost'): 1,
#           ('earn', 'almost', 'sure'): 1,
#           ('almost', 'sure', 'nomin'): 1,
#           ('sure', 'nomin', 'scar'): 1,
#           ('nomin', 'scar', 'least'): 1,
#           ('scar', 'least', 'take'): 1,
#           ('least', 'take', 'joke'): 1,
#           ('take', 'joke', 'differ'): 1,
#           ('joke', 'differ', 'ledger'): 1,
#           ('differ', 'ledger', 'id'): 1,
#           ('ledger', 'id', 'say'): 1,
#           ('id', 'say', 'equal'): 1,
#           ('say', 'equal', 'good'): 1,
#           ('equal', 'good', 'main'): 1,
#           ('good', 'main', 'differ'): 1,
#           ('main', 'differ', 'might'): 1,
#           ('differ', 'might', 'ledger'): 1,
#           ('might', 'ledger', 'joke'): 1,
#           ('ledger', 'joke', 'ration'): 1,
#           ('joke', 'ration', 'act'): 1,
#           ('ration', 'act', 'insan'): 1,
#           ('act', 'insan', 'phoenix'): 1,
#           ('insan', 'phoenix', 'insan'): 1,
#           ('phoenix', 'insan', 'root'): 1,
#           ('insan', 'root', 'despit'): 1,
#           ('root', 'despit', 'movi'): 1,
#           ('despit', 'movi', 'superhero'): 1,
#           ('movi', 'superhero', 'villain'): 1,
#           ('superhero', 'villain', 'joke'): 1,
#           ('villain', 'joke', 'much'): 1,
#           ('joke', 'much', 'superior'): 1,
#           ('much', 'superior', 'move'): 1,
#           ('superior', 'move', 'gene'): 1,
#           ('move', 'gene', 'id'): 1,
#           ('gene', 'id', 'exclud'): 1,
#           ('id', 'exclud', 'dark'): 1,
#           ('exclud', 'dark', 'knight'): 1,
#           ('dark', 'knight', 'trilog'): 2,
#           ('knight', 'trilog', 'joke'): 1,
#           ('trilog', 'joke', 'easili'): 1,
#           ('joke', 'easili', 'good'): 1,
#           ('easili', 'good', 'plan'): 1,
#           ('good', 'plan', 'move'): 1,
#           ('plan', 'move', 'least'): 1,
#           ('move', 'least', 'close'): 1,
#           ('least', 'close', 'smallscal'): 1,
#           ('close', 'smallscal', 'film'): 1,
#           ('smallscal', 'film', 'distinct'): 1,
#           ('film', 'distinct', 'style'): 1,
#           ('distinct', 'style', 'cinematographi'): 1,
#           ('style', 'cinematographi', 'can'): 1,
#           ('cinematographi', 'can', 'not'): 1,
#           ('can', 'not', 'appreci'): 1,
#           ('not', 'appreci', 'set'): 1,
#           ('appreci', 'set', 'cinephil'): 1,
#           ('set', 'cinephil', 'refer'): 1,
#           ('cinephil', 'refer', 'howev'): 1,
#           ('refer', 'howev', 'feel'): 1,
#           ('howev', 'feel', 'forc'): 1,
#           ('feel', 'forc', 'overlay'): 1,
#           ('forc', 'overlay', 'oppress'): 1,
#           ('overlay', 'oppress', 'notabl'): 1,
#           ('oppress', 'notabl', 'similar'): 1,
#           ('notabl', 'similar', 'scorses'): 1,
#           ('similar', 'scorses', 'taxi'): 1,
#           ('scorses', 'taxi', 'driver'): 1,
#           ('king', 'comedi', 'also'): 1,
#           ('comedi', 'also', 'chain'): 1,
#           ('also', 'chain', 'modern'): 1,
#           ('chain', 'modern', 'time'): 1,
#           ('modern', 'time', 'somewhat'): 1,
#           ('time', 'somewhat', 'refer'): 1,
#           ('somewhat', 'refer', 'eager'): 1,
#           ('refer', 'eager', 'see'): 1,
#           ('eager', 'see', 'noncomed'): 1,
#           ('see', 'noncomed', 'effort'): 1,
#           ('noncomed', 'effort', 'told'): 1,
#           ('effort', 'told', 'phillip'): 1,
#           ('told', 'phillip', 'movi'): 1,
#           ('phillip', 'movi', 'far'): 1,
#           ('movi', 'far', 'probabl'): 1,
#           ('far', 'probabl', 'best'): 1,
#           ('probabl', 'best', '2019'): 1,
#           ('best', '2019', 'worst'): 1,
#           ('2019', 'worst', 'contest'): 1,
#           ('worst', 'contest', 'far'): 1,
#           ('contest', 'far', 'door'): 1,
#           ('far', 'door', 'gloria'): 1,
#           ('door', 'gloria', 'upon'): 1,
#           ('gloria', 'upon', 'time'): 1,
#           ('upon', 'time', 'hollywood'): 2,
#           ('time', 'hollywood', 'convinc'): 1,
#           ('hollywood', 'convinc', 'sad'): 1,
#           ('convinc', 'sad', 'joaquin'): 1,
#           ('sad', 'joaquin', 'miss'): 1,
#           ('joaquin', 'miss', 'oscar'): 1,
#           ('miss', 'oscar', 'gladiat'): 1,
#           ('oscar', 'gladiat', 'compel'): 1,
#           ('gladiat', 'compel', 'villain'): 1,
#           ('compel', 'villain', 'quit'): 1,
#           ('villain', 'quit', 'confid'): 1,
#           ('quit', 'confid', 'win'): 1,
#           ('confid', 'win', 'joke'): 1,
#           ('win', 'joke', 'damn'): 1,
#           ('joke', 'damn', 'movi'): 1,
#           ('damn', 'movi', 'keep'): 1,
#           ('movi', 'keep', 'u'): 1,
#           ('keep', 'u', 'toe'): 1,
#           ('u', 'toe', 'time'): 1,
#           ('toe', 'time', 'predict'): 1,
#           ('time', 'predict', 'storylin'): 1,
#           ('predict', 'storylin', 'realli'): 1,
#           ('storylin', 'realli', 'deep'): 1,
#           ('realli', 'deep', 'interest'): 1,
#           ('deep', 'interest', 'plot'): 1,
#           ('interest', 'plot', 'forget'): 1,
#           ('plot', 'forget', 'mention'): 1,
#           ('forget', 'mention', 'act'): 1,
#           ('mention', 'act', 'damn'): 1,
#           ('act', 'damn', 'no'): 1,
#           ('damn', 'no', 'joaquin'): 1,
#           ('no', 'joaquin', 'teach'): 1,
#           ('joaquin', 'teach', 'u'): 1,
#           ('teach', 'u', 'realli'): 1,
#           ('u', 'realli', '5'): 1,
#           ('realli', '5', 'star'): 1,
#           ('5', 'star', 'act'): 1,
#           ('star', 'act', 'enjoy'): 1,
#           ('act', 'enjoy', 'movi'): 1,
#           ('enjoy', 'movi', 'get'): 1,
#           ('movi', 'get', 'wine'): 1,
#           ('get', 'wine', 'hand'): 1,
#           ('wine', 'hand', 'close'): 1,
#           ('hand', 'close', 'curtain'): 1,
#           ('close', 'curtain', 'turn'): 1,
#           ('curtain', 'turn', 'or'): 1,
#           ('turn', 'or', 'cellphon'): 1,
#           ('or', 'cellphon', 'put'): 1,
#           ('cellphon', 'put', 'disturb'): 1,
#           ('put', 'disturb', 'sign'): 1,
#           ('disturb', 'sign', 'or'): 1,
#           ('sign', 'or', 'door'): 1,
#           ('or', 'door', 'best'): 1,
#           ('door', 'best', 'dark'): 1,
#           ('best', 'dark', 'thrill'): 1,
#           ('dark', 'thrill', 'suspens'): 1,
#           ('thrill', 'suspens', 'movi'): 1,
#           ('suspens', 'movi', 'get'): 1,
#           ('movi', 'get', 'experi'): 1,
#           ('get', 'experi', 'give'): 1,
#           ('experi', 'give', 'watch'): 1,
#           ('give', 'watch', 'mani'): 1,
#           ('watch', 'mani', 'superhero'): 1,
#           ('mani', 'superhero', 'move'): 1,
#           ('superhero', 'move', 'come'): 1,
#           ('move', 'come', 'pike'): 1,
#           ('come', 'pike', 'often'): 1,
#           ('pike', 'often', 'compens'): 1,
#           ('often', 'compens', 'sensat'): 1,
#           ('compens', 'sensat', 'plot'): 1,
#           ('sensat', 'plot', 'involv'): 1,
#           ('plot', 'involv', 'great'): 1,
#           ('involv', 'great', 'special'): 1,
#           ('great', 'special', 'effect'): 1,
#           ('special', 'effect', 'nonstop'): 1,
#           ('effect', 'nonstop', 'action'): 1,
#           ('nonstop', 'action', 'fun'): 1,
#           ('action', 'fun', 'dont'): 1,
#           ('fun', 'dont', 'mean'): 1,
#           ('dont', 'mean', 'di'): 1,
#           ('mean', 'di', 'miss'): 1,
#           ('di', 'miss', 'truli'): 1,
#           ('miss', 'truli', 'psycholog'): 1,
#           ('truli', 'psycholog', 'drama'): 1,
#           ('psycholog', 'drama', 'dont'): 1,
#           ('drama', 'dont', 'get'): 1,
#           ('dont', 'get', 'head'): 1,
#           ('get', 'head', 'charact'): 1,
#           ('head', 'charact', 'film'): 1,
#           ('charact', 'film', 'incred'): 1,
#           ('film', 'incred', 'watch'): 1,
#           ('incred', 'watch', 'man'): 1,
#           ('watch', 'man', 'confront'): 1,
#           ('man', 'confront', 'demon'): 1,
#           ('confront', 'demon', 'see'): 1,
#           ('demon', 'see', 'made'): 1,
#           ('see', 'made', 'fun'): 1,
#           ('made', 'fun', 'attack'): 1,
#           ('fun', 'attack', 'beaten'): 1,
#           ('attack', 'beaten', 'respond'): 1,
#           ('beaten', 'respond', 'seen'): 1,
#           ('respond', 'seen', 'crazi'): 1,
#           ('seen', 'crazi', 'also'): 1,
#           ('crazi', 'also', 'find'): 1,
#           ('also', 'find', 'diminish'): 1,
#           ('find', 'diminish', 'eye'): 1,
#           ('diminish', 'eye', 'counselor'): 1,
#           ('eye', 'counselor', 'mother'): 1,
#           ('counselor', 'mother', 'kept'): 1,
#           ('mother', 'kept', 'secret'): 1,
#           ('kept', 'secret', 'thought'): 1,
#           ('secret', 'thought', 'gave'): 1,
#           ('thought', 'gave', 'u'): 1,
#           ('gave', 'u', 'foundat'): 1,
#           ('u', 'foundat', 'batman'): 1,
#           ('foundat', 'batman', 'method'): 1,
#           ('batman', 'method', 'without'): 1,
#           ('method', 'without', 'get'): 1,
#           ('without', 'get', 'deepli'): 1,
#           ('get', 'deepli', 'act'): 1,
#           ('deepli', 'act', 'atmospher'): 1,
#           ('act', 'atmospher', 'sophist'): 1,
#           ('atmospher', 'sophist', 'plot'): 1,
#           ('sophist', 'plot', 'make'): 1,
#           ('plot', 'make', 'realli'): 1,
#           ('make', 'realli', 'excel'): 1,
#           ('realli', 'excel', 'film'): 1,
#           ('excel', 'film', 'movi'): 1,
#           ('film', 'movi', 'affect'): 1,
#           ('movi', 'affect', 'way'): 1,
#           ('affect', 'way', 'make'): 1,
#           ('way', 'make', 'physic'): 1,
#           ('make', 'physic', 'pain'): 1,
#           ('physic', 'pain', 'experi'): 1,
#           ('pain', 'experi', 'good'): 1,
#           ('experi', 'good', 'way'): 1,
#           ('good', 'way', 'thought'): 1,
#           ('way', 'thought', 'film'): 1,
#           ('thought', 'film', 'good'): 1,
#           ('film', 'good', 'dont'): 1,
#           ('good', 'dont', 'get'): 1,
#           ('dont', 'get', 'hope'): 1,
#           ('get', 'hope', 'person'): 1,
#           ('hope', 'person', 'act'): 1,
#           ('person', 'act', 'amaz'): 1,
#           ('act', 'amaz', 'film'): 1,
#           ('amaz', 'film', 'good'): 1,
#           ('film', 'good', 'overal'): 1,
#           ('good', 'overal', 'think'): 1,
#           ('overal', 'think', 'masterpiec'): 1,
#           ('think', 'masterpiec', 'film'): 1,
#           ('masterpiec', 'film', 'year'): 1,
#           ('film', 'year', 'bit'): 1,
#           ('year', 'bit', 'vers'): 1,
#           ('bit', 'vers', 'throughout'): 1,
#           ('vers', 'throughout', 'review'): 1,
#           ('throughout', 'review', 'way'): 1,
#           ('review', 'way', 'dislik'): 1,
#           ('way', 'dislik', 'film'): 1,
#           ('dislik', 'film', 'thought'): 1,
#           ('film', 'thought', 'realli'): 1,
#           ('thought', 'realli', 'good'): 1,
#           ('realli', 'good', 'overhyp'): 1,
#           ('good', 'overhyp', 'feel'): 1,
#           ('overhyp', 'feel', 'though'): 1,
#           ('feel', 'though', 'lot'): 1,
#           ('though', 'lot', '1010'): 1,
#           ('lot', '1010', 'review'): 1,
#           ('1010', 'review', 'pure'): 1,
#           ('review', 'pure', 'base'): 1,
#           ('pure', 'base', 'fact'): 1,
#           ('base', 'fact', 'alreadi'): 1,
#           ('fact', 'alreadi', 'amaz'): 1,
#           ('alreadi', 'amaz', 'review'): 1,
#           ('amaz', 'review', 'peopl'): 1,
#           ('review', 'peopl', 'want'): 1,
#           ('peopl', 'want', 'carri'): 1,
#           ('want', 'carri', 'prais'): 1,
#           ('carri', 'prais', 'joke'): 1,
#           ('prais', 'joke', 'film'): 1,
#           ('joke', 'film', 'releas'): 1,
#           ('film', 'releas', 'random'): 1,
#           ('releas', 'random', 'guy'): 1,
#           ('random', 'guy', 'situat'): 1,
#           ('guy', 'situat', 'dont'): 1,
#           ('situat', 'dont', 'think'): 1,
#           ('dont', 'think', 'review'): 1,
#           ('think', 'review', 'would'): 1,
#           ('review', 'would', 'high'): 1,
#           ('would', 'high', 'mayb'): 1,
#           ('high', 'mayb', 'that'): 1,
#           ('mayb', 'that', 'point'): 1,
#           ('that', 'point', 'movi'): 1,
#           ('point', 'movi', 'caus'): 1,
#           ('movi', 'caus', 'audienc'): 1,
#           ('caus', 'audienc', 'consid'): 1,
#           ('audienc', 'consid', 'mani'): 1,
#           ('consid', 'mani', 'topic'): 1,
#           ('mani', 'topic', 'moral'): 1,
#           ('topic', 'moral', 'particularli'): 1,
#           ('moral', 'particularli', 'poor'): 1,
#           ('particularli', 'poor', 'choic'): 1,
#           ('poor', 'choic', 'made'): 1,
#           ('choic', 'made', 'joke'): 1,
#           ('made', 'joke', 'joke'): 1,
#           ('joke', 'joke', 'reliabl'): 1,
#           ('joke', 'reliabl', 'movi'): 1,
#           ('reliabl', 'movi', 'antagonist'): 1,
#           ('movi', 'antagonist', 'usual'): 1,
#           ('antagonist', 'usual', 'think'): 1,
#           ('usual', 'think', 'give'): 1,
#           ('think', 'give', 'realist'): 1,
#           ('give', 'realist', 'view'): 1,
#           ('realist', 'view', 'bad'): 1,
#           ('view', 'bad', 'peopl'): 1,
#           ('bad', 'peopl', 'usual'): 1,
#           ('peopl', 'usual', '100'): 1,
#           ('usual', '100', 'bad'): 1,
#           ('100', 'bad', 'way'): 1,
#           ('bad', 'way', 'societi'): 1,
#           ('way', 'societi', 'often'): 1,
#           ('societi', 'often', 'judg'): 1,
#           ('often', 'judg', 'import'): 1,
#           ('judg', 'import', 'know'): 1,
#           ('import', 'know', 'sympath'): 1,
#           ('know', 'sympath', 'joke'): 1,
#           ('sympath', 'joke', 'toward'): 1,
#           ('joke', 'toward', 'begin'): 1,
#           ('toward', 'begin', 'movi'): 1,
#           ('begin', 'movi', 'need'): 1,
#           ('movi', 'need', 'identifi'): 1,
#           ('need', 'identifi', 'threat'): 1,
#           ('identifi', 'threat', 'begin'): 1,
#           ('threat', 'begin', 'make'): 1,
#           ('begin', 'make', 'certain'): 1,
#           ('make', 'certain', 'bad'): 1,
#           ('certain', 'bad', 'choic'): 1,
#           ('bad', 'choic', 'movi'): 1,
#           ('choic', 'movi', 'suitabl'): 1,
#           ('movi', 'suitabl', 'adult'): 1,
#           ('suitabl', 'adult', 'will'): 1,
#           ('adult', 'will', 'pick'): 1,
#           ('will', 'pick', 'apart'): 1,
#           ('pick', 'apart', 'think'): 1,
#           ('apart', 'think', 'clinic'): 1,
#           ('think', 'clinic', 'isn'): 1,
#           ('clinic', 'isn', 'light'): 1,
#           ('isn', 'light', 'amus'): 1,
#           ('light', 'amus', 'substanc'): 1,
#           ('amus', 'substanc', 'make'): 1,
#           ('substanc', 'make', 'good'): 1,
#           ('make', 'good', 'agent'): 1,
#           ('good', 'agent', 'abl'): 1,
#           ('agent', 'abl', 'ponder'): 1,
#           ('abl', 'ponder', 'underli'): 1,
#           ('ponder', 'underli', 'theme'): 1,
#           ('underli', 'theme', 'hand'): 1,
#           ('theme', 'hand', 'thought'): 1,
#           ('hand', 'thought', 'isn'): 1,
#           ('thought', 'isn', 'best'): 1,
#           ('isn', 'best', 'movi'): 1,
#           ('best', 'movi', 'act'): 1,
#           ('movi', 'act', 'cinematographi'): 1,
#           ('act', 'cinematographi', 'sound'): 1,
#           ('cinematographi', 'sound', 'design'): 1,
#           ('sound', 'design', 'script'): 1,
#           ('design', 'script', 'phenomenon'): 1,
#           ('script', 'phenomenon', 'movi'): 1,
#           ('phenomenon', 'movi', 'triumph'): 1,
#           ('movi', 'triumph', 'joaquin'): 1,
#           ('triumph', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'deserv'): 1,
#           ('phoenix', 'deserv', 'oscar'): 1,
#           ('deserv', 'oscar', 'win'): 1,
#           ('oscar', 'win', 'th'): 1,
#           ('win', 'th', 'went'): 1,
#           ('th', 'went', 'film'): 1,
#           ('went', 'film', 'expect'): 1,
#           ('film', 'expect', 'allie'): 1,
#           ('expect', 'allie', 'classic'): 1,
#           ('allie', 'classic', 'base'): 1,
#           ('classic', 'base', 'review'): 1,
#           ('base', 'review', 'read'): 1,
#           ('review', 'read', 'end'): 1,
#           ('read', 'end', 'watch'): 1,
#           ('end', 'watch', 'decent'): 1,
#           ('watch', 'decent', 'film'): 1,
#           ('decent', 'film', 'overal'): 1,
#           ('film', 'overal', 'phoenix'): 1,
#           ('overal', 'phoenix', 'outstand'): 1,
#           ('phoenix', 'outstand', 'definit'): 1,
#           ('outstand', 'definit', 'part'): 1,
#           ('definit', 'part', 'feel'): 1,
#           ('part', 'feel', 'like'): 1,
#           ('feel', 'like', 'you'): 1,
#           ('like', 'you', 'seen'): 1,
#           ('you', 'seen', 'trailer'): 1,
#           ('seen', 'trailer', 'you'): 1,
#           ('trailer', 'you', 'seen'): 1,
#           ('you', 'seen', 'movi'): 1,
#           ('seen', 'movi', 'best'): 1,
#           ('movi', 'best', 'way'): 1,
#           ('best', 'way', 'describ'): 1,
#           ('way', 'describ', 'film'): 1,
#           ('describ', 'film', 'feel'): 1,
#           ('film', 'feel', 'like'): 1,
#           ('feel', 'like', '2'): 1,
#           ('like', '2', 'hour'): 1,
#           ('2', 'hour', 'version'): 1,
#           ('hour', 'version', 'trailer'): 1,
#           ('version', 'trailer', '2'): 1,
#           ('trailer', '2', 'hour'): 1,
#           ('2', 'hour', 'rel'): 1,
#           ('hour', 'rel', 'common'): 1,
#           ('rel', 'common', 'aunti'): 1,
#           ('common', 'aunti', 'felt'): 1,
#           ('aunti', 'felt', 'lot'): 1,
#           ('felt', 'lot', 'longerwhich'): 1,
#           ('lot', 'longerwhich', 'isn'): 1,
#           ('longerwhich', 'isn', 'good'): 1,
#           ('isn', 'good', 'id'): 1,
#           ('good', 'id', 'say'): 1,
#           ('id', 'say', 'much'): 1,
#           ('say', 'much', 'rental'): 1,
#           ('much', 'rental', 'theater'): 1,
#           ('rental', 'theater', 'movi'): 1,
#           ('theater', 'movi', 'kind'): 1,
#           ('movi', 'kind', 'just'): 1,
#           ('kind', 'just', 'need'): 1,
#           ('just', 'need', 'say'): 1,
#           ('need', 'say', 'everyth'): 1,
#           ('say', 'everyth', 'movi'): 1,
#           ('everyth', 'movi', 'wast'): 1,
#           ('movi', 'wast', 'everi'): 1,
#           ('wast', 'everi', 'singl'): 1,
#           ('everi', 'singl', 'way'): 1,
#           ('singl', 'way', 'joke'): 1,
#           ('way', 'joke', 'isn'): 1,
#           ('joke', 'isn', 'awesom'): 1,
#           ('isn', 'awesom', 'comic'): 1,
#           ('awesom', 'comic', 'book'): 1,
#           ('comic', 'book', 'movi'): 2,
#           ('book', 'movi', 'awesom'): 1,
#           ('movi', 'awesom', 'movi'): 1,
#           ('awesom', 'movi', 'period'): 1,
#           ('movi', 'period', 'offer'): 1,
#           ('period', 'offer', 'easi'): 1,
#           ('offer', 'easi', 'answer'): 1,
#           ('easi', 'answer', 'settl'): 1,
#           ('answer', 'settl', 'question'): 1,
#           ('settl', 'question', 'rais'): 1,
#           ('question', 'rais', 'cruel'): 1,
#           ('rais', 'cruel', 'societi'): 1,
#           ('cruel', 'societi', 'declin'): 1,
#           ('societi', 'declin', 'joaquin'): 1,
#           ('declin', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'fulli'): 1,
#           ('phoenix', 'fulli', 'commit'): 1,
#           ('fulli', 'commit', 'perform'): 1,
#           ('commit', 'perform', 'told'): 1,
#           ('perform', 'told', 'phillip'): 1,
#           ('told', 'phillip', 'wast'): 1,
#           ('phillip', 'wast', 'albeit'): 1,
#           ('wast', 'albeit', 'loo'): 1,
#           ('albeit', 'loo', 'invent'): 1,
#           ('loo', 'invent', 'do'): 1,
#           ('invent', 'do', 'sourc'): 1,
#           ('do', 'sourc', 'materi'): 1,
#           ('sourc', 'materi', 'make'): 1,
#           ('materi', 'make', 'joke'): 1,
#           ('make', 'joke', 'film'): 1,
#           ('joke', 'film', 'leav'): 1,
#           ('film', 'leav', 'comic'): 1,
#           ('leav', 'comic', 'book'): 1,
#           ('comic', 'book', 'fan'): 1,
#           ('book', 'fan', 'nonfan'): 1,
#           ('fan', 'nonfan', 'alik'): 1,
#           ('nonfan', 'alik', 'disturb'): 1,
#           ('alik', 'disturb', 'move'): 1,
#           ('disturb', 'move', 'right'): 1,
#           ('move', 'right', 'way'): 1,
#           ('right', 'way', 'realli'): 1,
#           ('way', 'realli', 'understand'): 1,
#           ('realli', 'understand', 'ten'): 1,
#           ('understand', 'ten', 'sure'): 1,
#           ('ten', 'sure', 'good'): 1,
#           ('sure', 'good', 'movi'): 1,
#           ('good', 'movi', 'good'): 1,
#           ('movi', 'good', 'act'): 1,
#           ('good', 'act', 'nice'): 1,
#           ('act', 'nice', 'shoot'): 1,
#           ('nice', 'shoot', 'plot'): 1,
#           ('shoot', 'plot', 'intrigu'): 1,
#           ('plot', 'intrigu', 'time'): 1,
#           ('intrigu', 'time', 'realli'): 1,
#           ('time', 'realli', 'long'): 1,
#           ('realli', 'long', 'somewhat'): 1,
#           ('long', 'somewhat', 'bore'): 1,
#           ('somewhat', 'bore', 'need'): 1,
#           ('bore', 'need', 'doublecheck'): 1,
#           ('need', 'doublecheck', 'gene'): 1,
#           ('doublecheck', 'gene', 'see'): 1,
#           ('gene', 'see', 'drama'): 1,
#           ('see', 'drama', 'crime'): 1,
#           ('drama', 'crime', 'drama'): 1,
#           ('crime', 'drama', 'thrill'): 1,
#           ('drama', 'thrill', 'said'): 1,
#           ('thrill', 'said', 'would'): 1,
#           ('said', 'would', 'put'): 1,
#           ('would', 'put', 'mayb'): 1,
#           ('put', 'mayb', '90'): 1,
#           ('mayb', '90', 'drama'): 1,
#           ('90', 'drama', 'rest'): 1,
#           ('drama', 'rest', 'thrill'): 1,
#           ('rest', 'thrill', 'miss'): 1,
#           ('thrill', 'miss', 'dialogu'): 1,
#           ('miss', 'dialogu', 'depth'): 1,
#           ('dialogu', 'depth', 'substanc'): 1,
#           ('depth', 'substanc', 'plot'): 1,
#           ('substanc', 'plot', 'realli'): 1,
#           ('plot', 'realli', 'somewhat'): 1,
#           ('realli', 'somewhat', 'crazi'): 1,
#           ('somewhat', 'crazi', 'person'): 1,
#           ('crazi', 'person', 'becom'): 1,
#           ('person', 'becom', 'bit'): 1,
#           ('becom', 'bit', 'brazier'): 1,
#           ('bit', 'brazier', 'sure'): 1,
#           ('brazier', 'sure', 'underton'): 1,
#           ('sure', 'underton', 'societi'): 1,
#           ('underton', 'societi', 'system'): 1,
#           ('societi', 'system', 'mean'): 1,
#           ('system', 'mean', 'charact'): 1,
#           ('mean', 'charact', 'peopl'): 1,
#           ('charact', 'peopl', 'bring'): 1,
#           ('peopl', 'bring', 'creat'): 1,
#           ('bring', 'creat', 'evil'): 1,
#           ('creat', 'evil', 'beast'): 1,
#           ('evil', 'beast', 'later'): 1,
#           ('beast', 'later', 'want'): 1,
#           ('later', 'want', 'destroy'): 1,
#           ('want', 'destroy', 'everyth'): 1,
#           ('destroy', 'everyth', 'absolut'): 1,
#           ('everyth', 'absolut', 'think'): 1,
#           ('absolut', 'think', 'intrigu'): 1,
#           ('think', 'intrigu', 'stori'): 1,
#           ('intrigu', 'stori', 'plot'): 1,
#           ('stori', 'plot', 'dialogu'): 1,
#           ('plot', 'dialogu', 'enough'): 1,
#           ('dialogu', 'enough', 'give'): 1,
#           ('enough', 'give', 'ten'): 1,
#           ('give', 'ten', 'worthi'): 1,
#           ('ten', 'worthi', 'watch'): 1,
#           ('worthi', 'watch', 'ye'): 1,
#           ('watch', 'ye', 'amaz'): 1,
#           ('ye', 'amaz', 'stop'): 1,
#           ('amaz', 'stop', 'watch'): 1,
#           ('stop', 'watch', 'move'): 1,
#           ('watch', 'move', 'joaquin'): 1,
#           ('move', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'award'): 1,
#           ('phoenix', 'award', 'oscar'): 1,
#           ('award', 'oscar', 'tremend'): 1,
#           ('oscar', 'tremend', 'act'): 1,
#           ('tremend', 'act', 'quit'): 1,
#           ('act', 'quit', 'reli'): 1,
#           ('quit', 'reli', 'critic'): 1,
#           ('reli', 'critic', 'review'): 1,
#           ('critic', 'review', 'year'): 1,
#           ('review', 'year', 'ago'): 1,
#           ('year', 'ago', 'notic'): 1,
#           ('ago', 'notic', 'movi'): 1,
#           ('notic', 'movi', 'critic'): 1,
#           ('movi', 'critic', 'rate'): 1,
#           ('critic', 'rate', 'low'): 1,
#           ('rate', 'low', 'viewer'): 1,
#           ('low', 'viewer', 'rate'): 1,
#           ('viewer', 'rate', 'high'): 1,
#           ('rate', 'high', 'said'): 1,
#           ('high', 'said', 'point'): 1,
#           ('said', 'point', 'critic'): 1,
#           ('point', 'critic', 'movi'): 1,
#           ('critic', 'movi', 'oh'): 1,
#           ('movi', 'oh', 'wrong'): 1,
#           ('oh', 'wrong', 'went'): 1,
#           ('wrong', 'went', 'saw'): 1,
#           ('went', 'saw', 'tone'): 1,
#           ('saw', 'tone', 'mon'): 1,
#           ('tone', 'mon', 'went'): 1,
#           ('mon', 'went', 'skeptic'): 1,
#           ('went', 'skeptic', 'w'): 1,
#           ('skeptic', 'w', 'low'): 1,
#           ('w', 'low', 'expect'): 1,
#           ('low', 'expect', 'knew'): 1,
#           ('expect', 'knew', 'expect'): 1,
#           ('knew', 'expect', 'typic'): 1,
#           ('expect', 'typic', 'super'): 1,
#           ('typic', 'super', 'hero'): 1,
#           ('super', 'hero', 'movi'): 2,
#           ('hero', 'movi', 'got'): 1,
#           ('movi', 'got', 'masterpiec'): 1,
#           ('got', 'masterpiec', 'went'): 1,
#           ('masterpiec', 'went', 'expect'): 1,
#           ...})

# %%
from collections import Counter
bi_grams = nltk.bigrams(iterations)
frequency_dist = nltk.FreqDist(bi_grams)
bi_grams_dict = dict(frequency_dist)
for word in bi_grams_dict:
  print( str(word) + ':' + str(bi_grams_dict[word] / iterations.count(word[0])))
# Out:
# Streaming output truncated to the last 5000 lines.
# ('refer', 'drop'):0.2
# ('drop', 'cring'):0.3333333333333333
# ('cring', 'littl'):0.2
# ('littl', 'edg'):0.1
# ('edg', 'moment'):0.16666666666666666
# ('moment', 'like'):0.09090909090909091
# ('like', 'dont'):0.017241379310344827
# ('dont', 'smile'):0.03125
# ('smile', 'sign'):0.5
# ('sign', 'scene'):0.3333333333333333
# ('scene', 'seem'):0.043478260869565216
# ('seem', 'design'):0.06666666666666667
# ('design', 'sole'):0.3333333333333333
# ('sole', 'someth'):1.0
# ('someth', 'hot'):0.0625
# ('hot', 'topic'):1.0
# ('topic', 'print'):0.5
# ('print', 'new'):1.0
# ('new', 'shirt'):0.08333333333333333
# ('shirt', 'everi'):1.0
# ('singl', 'plot'):0.25
# ('plot', 'twist'):0.13043478260869565
# ('twist', 'telegraph'):0.1
# ('telegraph', 'far'):1.0
# ('far', 'advanc'):0.06666666666666667
# ('advanc', 'lot'):1.0
# ('lot', 'u'):0.09090909090909091
# ('u', 'seen'):0.06666666666666667
# ('seen', 'exact'):0.041666666666666664
# ('exact', 'twist'):1.0
# ('twist', 'mani'):0.1
# ('mani', 'time'):0.11764705882352941
# ('time', 'want'):0.021739130434782608
# ('want', 'impress'):0.05
# ('impress', 'perhap'):0.3333333333333333
# ('perhap', 'actual'):0.3333333333333333
# ('actual', 'standalon'):0.058823529411764705
# ('standalon', 'movi'):1.0
# ('movi', 'instead'):0.004807692307692308
# ('instead', 'shock'):0.125
# ('shock', 'complet'):0.25
# ('complet', 'unnecessari'):0.06666666666666667
# ('unnecessari', 'tie'):0.25
# ('tie', 'batman'):0.5
# ('batman', 'univers'):0.14285714285714285
# ('univers', 'could'):0.14285714285714285
# ('could', 'done'):0.05
# ('done', 'someth'):0.125
# ('someth', 'interest'):0.0625
# ('interest', 'theme'):0.14285714285714285
# ('theme', 'dont'):0.14285714285714285
# ('get', 'wrong'):0.05263157894736842
# ('wrong', 'dont'):0.2
# ('dont', 'problem'):0.03125
# ('problem', 'superhero'):0.125
# ('move', 'feel'):0.02702702702702703
# ('feel', 'gratuit'):0.02631578947368421
# ('gratuit', 'someon'):1.0
# ('someon', 'came'):0.2
# ('came', 'idea'):0.2
# ('idea', 'pitch'):0.5
# ('pitch', 'execut'):1.0
# ('execut', 'told'):0.25
# ('told', 'sound'):0.05555555555555555
# ('sound', 'great'):0.25
# ('great', 'make'):0.02857142857142857
# ('make', 'batman'):0.029411764705882353
# ('batman', 'movi'):0.047619047619047616
# ('movi', 'somehow'):0.004807692307692308
# ('somehow', 'in'):0.5
# ('in', 'sorri'):0.125
# ('sorri', 'in'):0.3333333333333333
# ('in', 'movi'):0.125
# ('movi', 'tri'):0.009615384615384616
# ('tri', 'tell'):0.058823529411764705
# ('tell', 'hardheart'):0.2
# ('hardheart', 'yet'):1.0
# ('yet', 'deadseri'):0.25
# ('deadseri', 'speech'):1.0
# ('speech', 'mental'):1.0
# ('ill', 'modern'):0.034482758620689655
# ('modern', 'societi'):0.3333333333333333
# ('societi', 'simultan'):0.045454545454545456
# ('simultan', 'constantli'):1.0
# ('constantli', 'remind'):1.0
# ('remind', 'technic'):0.25
# ('technic', 'superhero'):0.3333333333333333
# ('movi', 'say'):0.004807692307692308
# ('say', 'write'):0.02564102564102564
# ('write', 'great'):0.1
# ('great', 'exampl'):0.02857142857142857
# ('exampl', 'good'):0.25
# ('act', 'product'):0.02564102564102564
# ('product', 'valu'):0.3333333333333333
# ('valu', 'can'):0.3333333333333333
# ('not', 'save'):0.25
# ('save', 'script'):0.3333333333333333
# ('script', 'step'):0.25
# ('step', 'tiresom'):0.25
# ('tiresom', 'stereotyp'):1.0
# ('stereotyp', 'failur'):1.0
# ('failur', 'delv'):0.5
# ('delv', 'charact'):1.0
# ('charact', 'ident'):0.017857142857142856
# ('ident', 'meet'):1.0
# ('meet', 'joke'):0.5
# ('joke', 'alreadi'):0.006896551724137931
# ('alreadi', 'balanc'):0.25
# ('balanc', 'call'):1.0
# ('call', 'descent'):0.14285714285714285
# ('descent', 'mad'):0.5
# ('mad', 'realli'):0.14285714285714285
# ('realli', 'coupl'):0.029411764705882353
# ('coupl', 'week'):0.2
# ('week', 'away'):0.5
# ('away', 'far'):0.1111111111111111
# ('far', 'descent'):0.06666666666666667
# ('descent', 'stroll'):0.25
# ('stroll', 'charact'):1.0
# ('charact', 'studi'):0.08928571428571429
# ('studi', 'despit'):0.2
# ('despit', 'claim'):0.14285714285714285
# ('claim', 'contrari'):0.25
# ('contrari', 'showcas'):1.0
# ('showcas', 'good'):1.0
# ('good', 'actor'):0.018867924528301886
# ('actor', 'overlay'):0.058823529411764705
# ('overlay', 'contort'):0.3333333333333333
# ('contort', 'bodi'):1.0
# ('bodi', 'laugh'):1.0
# ('laugh', 'magic'):0.05555555555555555
# ('magic', 'mistaken'):1.0
# ('mistaken', 'express'):1.0
# ('express', 'mad'):0.3333333333333333
# ('mad', 'past'):0.14285714285714285
# ('past', 'influenc'):0.14285714285714285
# ('influenc', 'conflict'):1.0
# ('conflict', 'semin'):1.0
# ('semin', 'moment'):1.0
# ('moment', 'creat'):0.09090909090909091
# ('creat', 'spiral'):0.14285714285714285
# ('spiral', 'perhap'):1.0
# ('perhap', 'realli'):0.3333333333333333
# ('realli', 'relationship'):0.029411764705882353
# ('relationship', 'gone'):0.5
# ('gone', 'sour'):1.0
# ('sour', 'would'):1.0
# ('would', 'justifi'):0.037037037037037035
# ('justifi', 'descent'):0.25
# ('descent', 'instead'):0.25
# ('instead', 'fait'):0.125
# ('fait', 'accompli'):1.0
# ('accompli', 'lazi'):1.0
# ('lazi', 'write'):1.0
# ('write', 'focus'):0.1
# ('focus', 'fanci'):0.3333333333333333
# ('fanci', 'long'):1.0
# ('long', 'shot'):0.125
# ('shot', 'joaquin'):0.2
# ('phoenix', 'danc'):0.013513513513513514
# ('danc', 'crazi'):0.16666666666666666
# ('crazi', 'produc'):0.14285714285714285
# ('produc', 'someth'):0.3333333333333333
# ('someth', 'valu'):0.0625
# ('valu', 'franchis'):0.3333333333333333
# ('franchis', 'joaquin'):0.3333333333333333
# ('give', 'heath'):0.045454545454545456
# ('ledger', 'run'):0.05
# ('run', 'money'):0.5
# ('money', 'true'):0.14285714285714285
# ('true', 'stori'):0.2
# ('stori', 'popcorn'):0.02631578947368421
# ('popcorn', 'fluff'):1.0
# ('fluff', 'comic'):1.0
# ('book', 'flick'):0.125
# ('flick', 'take'):0.5
# ('take', 'kiss'):0.04
# ('kiss', 'see'):0.3333333333333333
# ('movi', 'shut'):0.004807692307692308
# ('shut', 'ballot'):1.0
# ('ballot', 'oscar'):1.0
# ('oscar', 'joaquin'):0.05555555555555555
# ('joaquin', 'take'):0.016666666666666666
# ('take', 'one'):0.08
# ('one', 'home'):0.019230769230769232
# ('home', 'hand'):0.5
# ('hand', 'one'):0.14285714285714285
# ('best', 'origin'):0.029411764705882353
# ('origin', 'stori'):0.3125
# ('stori', 'ever'):0.02631578947368421
# ('ever', 'put'):0.07142857142857142
# ('put', 'downsid'):0.07142857142857142
# ('downsid', 'movi'):1.0
# ('movi', 'stand'):0.004807692307692308
# ('stand', 'alon'):0.25
# ('alon', 'film'):0.25
# ('film', 'sequel'):0.008620689655172414
# ('sequel', 'tie'):1.0
# ('tie', 'do'):0.25
# ('do', 'univers'):0.17647058823529413
# ('univers', 'told'):0.14285714285714285
# ('told', 'philip'):0.16666666666666666
# ('philip', 'take'):0.25
# ('joke', 'one'):0.006896551724137931
# ('one', 'pure'):0.019230769230769232
# ('pure', 'brillianc'):0.5
# ('brillianc', 'joaquin'):0.3333333333333333
# ('phoenix', 'joke'):0.013513513513513514
# ('deserv', 'didn'):0.1
# ('didn', 'steal'):0.1111111111111111
# ('steal', 'jack'):1.0
# ('jack', 'heath'):0.2
# ('heath', 'yet'):0.05
# ('yet', 'got'):0.25
# ('got', 'tast'):0.2
# ('tast', 'music'):0.5
# ('music', 'intens'):0.09090909090909091
# ('intens', 'realism'):0.5
# ('realism', 'perform'):1.0
# ('perform', 'stori'):0.022727272727272728
# ('stori', 'perfect'):0.05263157894736842
# ('perfect', 'combin'):0.07692307692307693
# ('combin', 'everyth'):0.5
# ('everyth', 'never'):0.1111111111111111
# ('never', 'felt'):0.09090909090909091
# ('felt', 'charact'):0.0625
# ('charact', 'like'):0.03571428571428571
# ('like', 'joke'):0.034482758620689655
# ('joke', 'could'):0.006896551724137931
# ('could', 'real'):0.05
# ('real', 'saw'):0.0625
# ('saw', 'phoenix'):0.14285714285714285
# ('phoenix', 'show'):0.013513513513513514
# ('show', 'u'):0.1111111111111111
# ('u', 'joke'):0.06666666666666667
# ('joke', 'societi'):0.013793103448275862
# ('societi', 'show'):0.045454545454545456
# ('u', 'power'):0.06666666666666667
# ('power', 'obtain'):0.3333333333333333
# ('obtain', 'philip'):1.0
# ('philip', 'hand'):0.25
# ('hand', 'perfect'):0.14285714285714285
# ('perfect', 'choic'):0.07692307692307693
# ('choic', 'music'):0.25
# ('music', 'camera'):0.09090909090909091
# ('camera', 'angl'):0.3333333333333333
# ('angl', 'light'):0.5
# ('light', 'everi'):0.2
# ('everi', 'import'):0.14285714285714285
# ('import', 'factor'):0.1111111111111111
# ('factor', 'overal'):0.5
# ('overal', 'expect'):0.09090909090909091
# ('expect', 'stori'):0.05
# ('perfect', 'mani'):0.07692307692307693
# ('mani', 'shock'):0.029411764705882353
# ('shock', 'turn'):0.25
# ('turn', 'happen'):0.25
# ('happen', 'realli'):0.0625
# ('realli', 'repres'):0.029411764705882353
# ('repres', 'today'):1.0
# ('today', 'societi'):0.25
# ('societi', 'first'):0.045454545454545456
# ('first', 'screen'):0.0625
# ('screen', 'would'):0.16666666666666666
# ('would', 'applaus'):0.037037037037037035
# ('applaus', '80'):0.25
# ('80', 'min'):1.0
# ('min', '8'):1.0
# ('8', 'perfect'):0.3333333333333333
# ('perfect', 'portrait'):0.07692307692307693
# ('portrait', 'declin'):1.0
# ('declin', 'insan'):0.5
# ('insan', 'joaquin'):0.2
# ('phoenix', 'portray'):0.04054054054054054
# ('portray', 'fearlessli'):0.06666666666666667
# ('fearlessli', 'perform'):1.0
# ('perform', 'lifetim'):0.045454545454545456
# ('lifetim', 'choreograph'):0.3333333333333333
# ('choreograph', 'impecc'):1.0
# ('impecc', 'told'):1.0
# ('phillip', 'noth'):0.06666666666666667
# ('noth', 'short'):0.1
# ('short', 'breathtak'):0.16666666666666666
# ('breathtak', 'cinematographi'):0.5
# ('cinematographi', 'backdrop'):0.043478260869565216
# ('backdrop', 'ideolog'):1.0
# ('ideolog', 'origin'):1.0
# ('origin', 'film'):0.1875
# ('film', 'complex'):0.008620689655172414
# ('complex', 'charact'):1.0
# ('charact', 'compliment'):0.017857142857142856
# ('compliment', 'superb'):1.0
# ('superb', 'soundtrack'):0.5
# ('soundtrack', 'act'):0.25
# ('act', 'hauntingli'):0.02564102564102564
# ('hauntingli', 'beauti'):1.0
# ('beauti', 'film'):0.25
# ('film', 'definit'):0.008620689655172414
# ('definit', '1010'):0.07692307692307693
# ('1010', 'edit'):0.2
# ('edit', 'bring'):0.3333333333333333
# ('bring', 'part'):0.125
# ('part', '2'):0.07142857142857142
# ('2', 'plssssss'):0.16666666666666666
# ('plssssss', 'want'):1.0
# ('want', 'expect'):0.05
# ('expect', 'masterpiec'):0.05
# ('masterpiec', 'oscar'):0.047619047619047616
# ('oscar', 'worthi'):0.1111111111111111
# ('worthi', 'film'):0.25
# ('film', 'hope'):0.008620689655172414
# ('hope', 'actual'):0.05
# ('actual', 'didn'):0.058823529411764705
# ('didn', 'enjoy'):0.1111111111111111
# ('enjoy', 'watch'):0.1111111111111111
# ('watch', 'movi'):0.06521739130434782
# ('movi', 'messag'):0.004807692307692308
# ('messag', 'slow'):0.14285714285714285
# ('slow', 'joke'):0.07142857142857142
# ('joke', 'turn'):0.006896551724137931
# ('turn', 'son'):0.25
# ('son', 'schizophren'):1.0
# ('schizophren', 'went'):1.0
# ('went', 'crazi'):0.09090909090909091
# ('crazi', 'slight'):0.14285714285714285
# ('slight', 'amount'):1.0
# ('amount', 'build'):0.5
# ('build', 'dont'):0.1
# ('dont', 'see'):0.0625
# ('see', 'anyon'):0.03333333333333333
# ('anyon', 'could'):0.3333333333333333
# ('could', 'relat'):0.05
# ('relat', 'charact'):0.2857142857142857
# ('charact', 'laugh'):0.017857142857142856
# ('laugh', 'lame'):0.05555555555555555
# ('lame', 'act'):1.0
# ('act', 'way'):0.02564102564102564
# ('way', 'everyon'):0.029411764705882353
# ('everyon', 'in'):0.1111111111111111
# ('in', 'stun'):0.125
# ('stun', '910'):0.2
# ('910', 'rate'):0.5
# ('rate', 'right'):0.09090909090909091
# ('right', 'hell'):0.07692307692307693
# ('hell', 'phoenix'):0.5
# ('phoenix', 'convinc'):0.02702702702702703
# ('convinc', 'alway'):0.16666666666666666
# ('alway', 'meant'):0.2
# ('meant', 'joke'):0.5
# ('joke', 'movi'):0.041379310344827586
# ('movi', 'went'):0.004807692307692308
# ('went', 'beyond'):0.09090909090909091
# ('beyond', 'expect'):0.5
# ('expect', 'mani'):0.05
# ('mani', 'emot'):0.058823529411764705
# ('emot', 'went'):0.16666666666666666
# ('went', 'coupl'):0.09090909090909091
# ('coupl', 'hour'):0.2
# ('hour', 'think'):0.1
# ('think', 'rate'):0.037037037037037035
# ('rate', 'r'):0.09090909090909091
# ('r', 'phoenix'):1.0
# ('phoenix', 'abl'):0.013513513513513514
# ('abl', 'clock'):0.2
# ('clock', 'joke'):1.0
# ('joke', 'full'):0.006896551724137931
# ('full', 'psychic'):0.5
# ('psychic', 'potenti'):0.25
# ('potenti', 'charact'):0.25
# ('charact', 'meant'):0.017857142857142856
# ('meant', 'amaz'):0.5
# ('amaz', 'stori'):0.14285714285714285
# ('stori', 'call'):0.02631578947368421
# ('call', 'mean'):0.14285714285714285
# ('mean', 'build'):0.1111111111111111
# ('build', 'second'):0.1
# ('second', 'movi'):0.3333333333333333
# ('movi', 'mayb'):0.004807692307692308
# ('mayb', 'one'):0.14285714285714285
# ('one', 'batman'):0.019230769230769232
# ('batman', 'hope'):0.047619047619047616
# ('hope', 'high'):0.05
# ('high', 'point'):0.07692307692307693
# ('point', 'nevertheless'):0.07142857142857142
# ('nevertheless', 'brilliant'):1.0
# ('brilliant', 'goddamn'):0.16666666666666666
# ('goddamn', 'movi'):1.0
# ('best', 'joke'):0.058823529411764705
# ('joke', 'ever'):0.013793103448275862
# ('ever', 'play'):0.07142857142857142
# ('play', 'hand'):0.14285714285714285
# ('hand', 'pool'):0.14285714285714285
# ('pool', 'need'):0.5
# ('need', 'money'):0.041666666666666664
# ('money', 'need'):0.14285714285714285
# ('need', 'digniti'):0.041666666666666664
# ('digniti', 'respect'):1.0
# ('respect', 'co'):0.5
# ('co', 'take'):1.0
# ('take', 'human'):0.04
# ('human', 'dont'):0.3333333333333333
# ('dont', 'money'):0.03125
# ('money', 'remind'):0.14285714285714285
# ('remind', 'good'):0.25
# ('good', 'boy'):0.018867924528301886
# ('boy', 'like'):0.2
# ('like', 'politician'):0.017241379310344827
# ('politician', 'feel'):1.0
# ('feel', 'frustrat'):0.02631578947368421
# ('frustrat', 'peopl'):0.5
# ('peopl', 'lower'):0.02564102564102564
# ('lower', 'class'):0.5
# ('class', 'accept'):0.14285714285714285
# ('accept', 'fund'):0.5
# ('fund', 'champion'):1.0
# ('champion', 'movi'):1.0
# ('movi', 'joke'):0.019230769230769232
# ('joke', 'life'):0.006896551724137931
# ('life', 'begin'):0.08333333333333333
# ('begin', 'get'):0.1
# ('get', 'take'):0.02631578947368421
# ('take', 'next'):0.04
# ('next', 'ingredi'):0.5
# ('ingredi', 'king'):1.0
# ('comedi', 'requir'):0.14285714285714285
# ('requir', 'dream'):0.5
# ('dream', 'dark'):0.5
# ('knight', 'taxi'):0.09090909090909091
# ('driver', 'mix'):0.09090909090909091
# ('mix', 'ladi'):0.5
# ('ladi', 'gentleman'):1.0
# ('gentleman', 'joke'):1.0
# ('joke', '1010'):0.006896551724137931
# ('1010', 'amaz'):0.2
# ('stori', 'brilliant'):0.02631578947368421
# ('brilliant', 'take'):0.16666666666666666
# ('take', 'magnific'):0.04
# ('magnific', 'cinematographi'):0.3333333333333333
# ('cinematographi', 'someon'):0.043478260869565216
# ('someon', 'step'):0.2
# ('step', 'safe'):0.25
# ('safe', 'game'):0.5
# ('game', 'play'):0.5
# ('play', 'superhero'):0.14285714285714285
# ('also', 'boy'):0.045454545454545456
# ('boy', 'movi'):0.2
# ('movi', 'gritti'):0.004807692307692308
# ('gritti', 'real'):0.3333333333333333
# ('real', 'insan'):0.0625
# ('insan', 'dark'):0.1
# ('dark', 'sometim'):0.03125
# ('sometim', 'quit'):0.16666666666666666
# ('quit', 'disturb'):0.09090909090909091
# ('disturb', 'peopl'):0.09090909090909091
# ('peopl', 'dont'):0.02564102564102564
# ('dont', 'want'):0.09375
# ('want', 'accept'):0.05
# ('accept', 'what'):0.5
# ('what', 'shown'):0.3333333333333333
# ('shown', 'movi'):0.5
# ('movi', 'terribl'):0.014423076923076924
# ('terribl', 'realiti'):0.16666666666666666
# ('realiti', 'face'):0.16666666666666666
# ('face', 'everyday'):0.16666666666666666
# ('everyday', 'refus'):1.0
# ('refus', 'proper'):1.0
# ('proper', 'care'):0.2
# ('care', 'normal'):0.2
# ('normal', 'peopl'):1.0
# ('peopl', 'start'):0.02564102564102564
# ('start', 'compar'):0.1
# ('compar', 'movi'):0.2
# ('movi', 'one'):0.004807692307692308
# ('one', 'greatest'):0.038461538461538464
# ('greatest', 'like'):0.5
# ('like', 'dark'):0.05172413793103448
# ('knight', 'act'):0.09090909090909091
# ('act', 'wise'):0.02564102564102564
# ('wise', 'heath'):1.0
# ('ledger', 'betray'):0.05
# ('betray', 'joke'):1.0
# ('joke', 'wouldn'):0.006896551724137931
# ('wouldn', 'say'):0.3333333333333333
# ('movi', 'better'):0.004807692307692308
# ('better', 'otherwis'):0.047619047619047616
# ('otherwis', 'stand'):0.3333333333333333
# ('stand', 'tall'):0.25
# ('tall', 'amongst'):1.0
# ('amongst', 'greatest'):1.0
# ('like', 'godfath'):0.017241379310344827
# ('godfath', 'taxi'):1.0
# ('driver', 'citizen'):0.09090909090909091
# ('citizen', 'lane'):0.5
# ('lane', 'dark'):1.0
# ('knight', 'come'):0.09090909090909091
# ('come', 'inevit'):0.0625
# ('inevit', 'comparison'):1.0
# ('comparison', 'who'):0.25
# ('who', 'better'):1.0
# ('better', 'joke'):0.09523809523809523
# ('joke', 'heath'):0.006896551724137931
# ('heath', 'joaquin'):0.05
# ('joaquin', 'answer'):0.016666666666666666
# ('answer', 'phenomenon'):0.5
# ('phenomenon', 'job'):0.2
# ('job', 'joke'):0.16666666666666666
# ('joke', 'charact'):0.020689655172413793
# ('charact', 'fortun'):0.017857142857142856
# ('fortun', 'play'):1.0
# ('play', 'two'):0.14285714285714285
# ('two', 'greatest'):0.1111111111111111
# ('greatest', 'actor'):0.25
# ('actor', 'definit'):0.058823529411764705
# ('definit', 'top'):0.15384615384615385
# ('top', 'contend'):0.3333333333333333
# ('contend', 'scar'):1.0
# ('scar', 'person'):0.25
# ('person', 'think'):0.0625
# ('think', 'would'):0.037037037037037035
# ('would', 'take'):0.037037037037037035
# ('take', 'away'):0.08
# ('away', 'best'):0.1111111111111111
# ('best', 'actor'):0.058823529411764705
# ('actor', '2cinematographi'):0.058823529411764705
# ('2cinematographi', 'origin'):1.0
# ('origin', 'score'):0.0625
# ('score', 'upon'):0.05
# ('hollywood', 'lose'):0.14285714285714285
# ('lose', 'make'):0.5
# ('make', 'hairstyl'):0.029411764705882353
# ('hairstyl', 'categori'):1.0
# ('categori', 'would'):0.25
# ('would', 'definit'):0.037037037037037035
# ('definit', 'joke'):0.07692307692307693
# ('joke', 'thought'):0.006896551724137931
# ('thought', 'movi'):0.07142857142857142
# ('movi', 'complet'):0.004807692307692308
# ('complet', 'utter'):0.06666666666666667
# ('utter', 'garag'):0.5
# ('garag', 'dont'):0.2
# ('dont', 'understand'):0.125
# ('understand', 'peopl'):0.06666666666666667
# ('peopl', 'like'):0.07692307692307693
# ('like', 'movi'):0.05172413793103448
# ('much', 'charact'):0.10344827586206896
# ('charact', 'doesn'):0.017857142857142856
# ('doesn', 'even'):0.08333333333333333
# ('even', 'stay'):0.037037037037037035
# ('stay', 'true'):0.25
# ('true', 'comic'):0.2
# ('comic', 'director'):0.047619047619047616
# ('director', 'flat'):0.1
# ('flat', 'said'):0.5
# ('said', 'didn'):0.2
# ('didn', 'made'):0.1111111111111111
# ('made', 'seem'):0.09090909090909091
# ('seem', 'like'):0.2
# ('like', 'part'):0.017241379310344827
# ('part', 'gotham'):0.07142857142857142
# ('gotham', 'fall'):1.0
# ('fall', 'littl'):0.16666666666666666
# ('littl', 'boy'):0.1
# ('boy', 'laugh'):0.2
# ('laugh', 'problem'):0.05555555555555555
# ('problem', 'hate'):0.125
# ('hate', 'review'):0.2
# ('review', 'make'):0.04
# ('make', 'film'):0.058823529411764705
# ('far', 'better'):0.06666666666666667
# ('better', 'actual'):0.047619047619047616
# ('actual', 'dont'):0.058823529411764705
# ('wrong', 'technic'):0.2
# ('technic', 'extrem'):0.3333333333333333
# ('extrem', 'well'):0.5
# ('well', 'done'):0.13333333333333333
# ('done', 'phoenix'):0.125
# ('perform', 'realli'):0.022727272727272728
# ('realli', 'quit'):0.029411764705882353
# ('quit', 'extraordinari'):0.09090909090909091
# ('extraordinari', 'definit'):0.5
# ('definit', 'look'):0.07692307692307693
# ('look', 'oscar'):0.0625
# ('oscar', 'nomin'):0.05555555555555555
# ('nomin', 'despit'):0.2
# ('despit', 'excel'):0.14285714285714285
# ('excel', 'write'):0.14285714285714285
# ('write', 'act'):0.1
# ('direct', 'film'):0.07142857142857142
# ('film', 'kind'):0.017241379310344827
# ('kind', 'bore'):0.2222222222222222
# ('bore', 'moment'):0.06666666666666667
# ('moment', 'sure'):0.09090909090909091
# ('sure', 'disturb'):0.0625
# ('disturb', 'element'):0.09090909090909091
# ('element', 'but'):0.25
# ('but', 'watch'):1.0
# ('watch', 'would'):0.043478260869565216
# ('would', 'look'):0.037037037037037035
# ('look', 'mani'):0.0625
# ('time', 'film'):0.021739130434782608
# ('film', 'lack'):0.017241379310344827
# ('lack', 'excit'):0.1111111111111111
# ('excit', 'final'):0.2
# ('final', 'act'):0.16666666666666666
# ('act', 'excel'):0.02564102564102564
# ('excel', 'felt'):0.14285714285714285
# ('felt', 'like'):0.25
# ('like', 'took'):0.017241379310344827
# ('took', 'forev'):0.2
# ('forev', 'get'):0.5
# ('get', 'one'):0.02631578947368421
# ('best', 'move'):0.08823529411764706
# ('move', 'year'):0.05405405405405406
# ('year', '100'):0.041666666666666664
# ('100', 'oscar'):0.5
# ('worthi', 'joaquin'):0.25
# ('deliv', 'one'):0.3333333333333333
# ('best', 'perform'):0.08823529411764706
# ('perform', 'give'):0.022727272727272728
# ('give', 'ever'):0.09090909090909091
# ('ever', 'scene'):0.07142857142857142
# ('scene', 'serious'):0.043478260869565216
# ('serious', 'unbeliev'):0.2
# ('unbeliev', 'dare'):1.0
# ('dare', 'say'):1.0
# ('say', 'better'):0.05128205128205128
# ('better', 'heath'):0.09523809523809523
# ('ledger', 'joaquin'):0.05
# ('doesn', 'win'):0.16666666666666666
# ('win', 'oscar'):0.2222222222222222
# ('oscar', 'best'):0.05555555555555555
# ('actor', 'joke'):0.11764705882352941
# ('joke', 'doesn'):0.013793103448275862
# ('win', 'least'):0.1111111111111111
# ('least', 'best'):0.2
# ('best', 'screenplay'):0.029411764705882353
# ('screenplay', 'one'):0.16666666666666666
# ('one', 'biggest'):0.019230769230769232
# ('biggest', 'oscar'):1.0
# ('oscar', 'snub'):0.05555555555555555
# ('snub', 'time'):1.0
# ('time', 'joaquín'):0.021739130434782608
# ('joaquín', 'phoenix'):1.0
# ('convinc', 'laugh'):0.16666666666666666
# ('laugh', 'look'):0.05555555555555555
# ('look', 'like'):0.125
# ('like', 'beaten'):0.017241379310344827
# ('beaten', 'dog'):0.3333333333333333
# ('dog', 'brutal'):1.0
# ('brutal', 'enjoy'):0.25
# ('enjoy', '5'):0.1111111111111111
# ('5', 'minut'):0.5
# ('minut', 'world'):0.25
# ('world', 'mean'):0.1111111111111111
# ('mean', 'bad'):0.1111111111111111
# ('bad', 'bad'):0.05555555555555555
# ('bad', 'hit'):0.05555555555555555
# ('hit', 'back'):0.3333333333333333
# ('back', 'chao'):0.14285714285714285
# ('chao', 'anarchi'):0.3333333333333333
# ('anarchi', 'whatev'):1.0
# ('whatev', 'inspir'):0.5
# ('inspir', 'bye'):0.125
# ('bye', 'clown'):1.0
# ('clown', 'kill'):0.1111111111111111
# ('kill', '3'):0.16666666666666666
# ('3', 'gulli'):0.2
# ('gulli', 'stupid'):1.0
# ('stupid', 'excess'):0.25
# ('excess', 'brutal'):1.0
# ('brutal', 'name'):0.25
# ('name', 'ye'):0.25
# ('ye', 'director'):0.1111111111111111
# ('director', 'hanov'):0.2
# ('hanov', '3'):0.5
# ('3', 'dont'):0.2
# ('want', 'parti'):0.05
# ('parti', 'brutal'):1.0
# ('brutal', 'bore'):0.25
# ('bore', 'trailer'):0.06666666666666667
# ('movi', 'may'):0.004807692307692308
# ('may', 'seem'):0.2222222222222222
# ('like', 'potenti'):0.017241379310344827
# ('potenti', 'action'):0.25
# ('action', 'pack'):0.05555555555555555
# ('pack', 'movi'):1.0
# ('movi', 'movi'):0.014423076923076924
# ('movi', 'clearli'):0.009615384615384616
# ('clearli', 'came'):0.3333333333333333
# ('came', 'theater'):0.2
# ('theater', 'intend'):0.25
# ('intend', 'progress'):1.0
# ('progress', 'charact'):0.3333333333333333
# ('studi', 'shouldn'):0.2
# ('shouldn', 'go'):0.5
# ('go', 'movi'):0.0625
# ('movi', 'expect'):0.004807692307692308
# ('expect', 'intens'):0.05
# ('intens', 'action'):0.5
# ('action', 'joke'):0.16666666666666666
# ('joke', 'know'):0.006896551724137931
# ('know', 'past'):0.047619047619047616
# ('past', 'movi'):0.14285714285714285
# ('movi', 'arthur'):0.004807692307692308
# ('arthur', 'fleck'):0.2777777777777778
# ('fleck', 'becom'):0.08333333333333333
# ('becom', 'joke'):0.2727272727272727
# ('joke', 'seen'):0.006896551724137931
# ('mani', 'bad'):0.029411764705882353
# ('bad', 'review'):0.05555555555555555
# ('review', 'bore'):0.04
# ('bore', 'slow'):0.06666666666666667
# ('slow', 'movi'):0.07142857142857142
# ('movi', 'believ'):0.004807692307692308
# ('believ', 'utter'):0.125
# ('utter', 'perfect'):0.5
# ('perfect', 'first'):0.07692307692307693
# ('first', 'part'):0.0625
# ('part', 'movi'):0.14285714285714285
# ('movi', 'begin'):0.004807692307692308
# ('begin', 'understand'):0.1
# ('understand', 'arthur'):0.06666666666666667
# ('arthur', 'person'):0.027777777777777776
# ('person', 'interact'):0.0625
# ('interact', 'everyon'):1.0
# ('everyon', 'life'):0.1111111111111111
# ('life', 'good'):0.08333333333333333
# ('good', 'bad'):0.05660377358490566
# ('bad', 'whole'):0.05555555555555555
# ('whole', 'point'):0.2222222222222222
# ('point', 'charact'):0.07142857142857142
# ('studi', 'evolut'):0.2
# ('evolut', 'far'):0.3333333333333333
# ('far', 'away'):0.13333333333333333
# ('away', 'one'):0.1111111111111111
# ('greatest', 'evolut'):0.25
# ('evolut', 'charact'):0.3333333333333333
# ('charact', 'ever'):0.017857142857142856
# ('movi', 'joaquin'):0.004807692307692308
# ('perform', 'far'):0.022727272727272728
# ('far', 'best'):0.06666666666666667
# ('best', 'act'):0.058823529411764705
# ('act', 'seen'):0.02564102564102564
# ('movi', 'possibl'):0.004807692307692308
# ('possibl', 'last'):0.25
# ('decad', 'see'):0.16666666666666666
# ('see', 'challeng'):0.03333333333333333
# ('challeng', 'person'):0.3333333333333333
# ('person', 'challeng'):0.0625
# ('challeng', 'societi'):0.3333333333333333
# ('societi', 'complet'):0.045454545454545456
# ('complet', 'break'):0.06666666666666667
# ('break', 'time'):0.16666666666666666
# ('time', 'joaquin'):0.021739130434782608
# ('joaquin', 'isn'):0.016666666666666666
# ('isn', 'act'):0.14285714285714285
# ('act', 'revolv'):0.02564102564102564
# ('revolv', 'throughout'):0.2
# ('throughout', 'movi'):0.2
# ('movi', 'anyon'):0.004807692307692308
# ('anyon', 'think'):0.16666666666666666
# ('think', 'doesn'):0.037037037037037035
# ('doesn', 'put'):0.08333333333333333
# ('put', 'oscar'):0.07142857142857142
# ('win', 'perform'):0.1111111111111111
# ('perform', 'there'):0.022727272727272728
# ('there', 'eat'):0.14285714285714285
# ('eat', 'mind'):0.3333333333333333
# ('mind', 'ye'):0.16666666666666666
# ('ye', 'movi'):0.2222222222222222
# ('movi', 'slow'):0.009615384615384616
# ('slow', 'start'):0.07142857142857142
# ('start', 'couldn'):0.1
# ('couldn', 'jump'):0.25
# ('jump', 'joke'):1.0
# ('joke', 'chao'):0.006896551724137931
# ('chao', 'need'):0.3333333333333333
# ('need', 'know'):0.041666666666666664
# ('know', 'came'):0.047619047619047616
# ('came', 'begin'):0.2
# ('begin', 'whole'):0.1
# ('whole', 'compil'):0.1111111111111111
# ('compil', 'movi'):1.0
# ('movi', 'amaz'):0.004807692307692308
# ('amaz', 'complet'):0.07142857142857142
# ('complet', 'oscar'):0.06666666666666667
# ('oscar', 'deserv'):0.05555555555555555
# ('deserv', 'perform'):0.1
# ('perform', 'joaquin'):0.09090909090909091
# ('joaquin', 'choreographi'):0.016666666666666666
# ('choreographi', 'cinematographi'):1.0
# ('cinematographi', 'score'):0.043478260869565216
# ('score', 'everyth'):0.05
# ('everyth', 'perfect'):0.1111111111111111
# ('perfect', 'harmoni'):0.07692307692307693
# ('harmoni', 'may'):1.0
# ('may', 'lot'):0.1111111111111111
# ('lot', 'controversi'):0.09090909090909091
# ('controversi', 'surround'):0.3333333333333333
# ('surround', 'movi'):0.3333333333333333
# ('movi', 'team'):0.004807692307692308
# ('team', 'put'):1.0
# ('put', 'togeth'):0.07142857142857142
# ('togeth', 'perfect'):0.5
# ('perfect', 'movi'):0.07692307692307693
# ('movi', 'piti'):0.004807692307692308
# ('piti', 'can'):1.0
# ('can', 'appreci'):0.1111111111111111
# ('appreci', 'tear'):0.25
# ('tear', 'sweat'):0.3333333333333333
# ('sweat', 'emot'):1.0
# ('went', 'make'):0.09090909090909091
# ('make', 'movi'):0.058823529411764705
# ('movi', 'alway'):0.004807692307692308
# ('alway', 'one'):0.2
# ('one', 'side'):0.019230769230769232
# ('side', 'movi'):0.3333333333333333
# ('movi', 'refer'):0.004807692307692308
# ('refer', 'marvel'):0.2
# ('marvel', 'do'):0.3333333333333333
# ('do', 'feel'):0.058823529411764705
# ('like', 'marvel'):0.017241379310344827
# ('marvel', 'soon'):0.3333333333333333
# ('soon', 'much'):1.0
# ('better', 'overal'):0.047619047619047616
# ('overal', 'move'):0.09090909090909091
# ('move', 'do'):0.05405405405405406
# ('do', 'put'):0.058823529411764705
# ('put', 'trash'):0.07142857142857142
# ('trash', 'joke'):0.3333333333333333
# ('joke', 'far'):0.006896551724137931
# ('away', 'favorit'):0.1111111111111111
# ('favorit', 'comic'):0.3333333333333333
# ('even', 'though'):0.07407407407407407
# ('though', 'take'):0.09090909090909091
# ('take', 'complet'):0.04
# ('complet', 'differ'):0.13333333333333333
# ('differ', 'spin'):0.06666666666666667
# ('spin', 'comic'):0.5
# ('comic', 'move'):0.047619047619047616
# ('move', 'appreci'):0.02702702702702703
# ('appreci', 'evolut'):0.25
# ('evolut', 'appreci'):0.3333333333333333
# ('appreci', 'movi'):0.25
# ('movi', 'action'):0.004807692307692308
# ('action', 'movi'):0.1111111111111111
# ('realli', 'lip'):0.029411764705882353
# ('lip', 'tear'):0.3333333333333333
# ('tear', 'emot'):0.3333333333333333
# ('emot', 'one'):0.08333333333333333
# ('one', 'movi'):0.019230769230769232
# ('movi', 'ad'):0.004807692307692308
# ('ad', 'wild'):0.3333333333333333
# ('wild', 'suspens'):0.5
# ('suspens', 'kick'):0.3333333333333333
# ('kick', 'comic'):1.0
# ('movi', 'done'):0.004807692307692308
# ('done', 'film'):0.125
# ('film', 'mental'):0.017241379310344827
# ('ill', 'specif'):0.034482758620689655
# ('specif', 'mental'):1.0
# ('ill', 'call'):0.034482758620689655
# ('call', 'creativ'):0.14285714285714285
# ('creativ', 'diarrhoea'):0.2
# ('diarrhoea', 'serious'):1.0
# ('serious', 'though'):0.2
# ('though', 'soon'):0.09090909090909091
# ('much', 'wrong'):0.034482758620689655
# ('wrong', 'movi'):0.2
# ('movi', 'wont'):0.004807692307692308
# ('wont', 'even'):0.25
# ('even', 'start'):0.037037037037037035
# ('start', 'knew'):0.1
# ('knew', 'joke'):0.5
# ('joke', 'sob'):0.006896551724137931
# ('sob', 'stori'):1.0
# ('stori', 'hope'):0.02631578947368421
# ('hope', 'artist'):0.05
# ('artist', 'success'):0.5
# ('success', 'went'):0.25
# ('went', 'went'):0.09090909090909091
# ('went', 'see'):0.09090909090909091
# ('see', 'anyway'):0.03333333333333333
# ('anyway', 'ill'):0.5
# ('ill', 'start'):0.034482758620689655
# ('start', 'point'):0.1
# ('point', 'review'):0.07142857142857142
# ('review', 'observ'):0.04
# ('observ', 'even'):1.0
# ('even', 'joke'):0.07407407407407407
# ('joke', 'he'):0.006896551724137931
# ('he', 'suav'):0.1
# ('suav', 'he'):1.0
# ('he', 'witti'):0.1
# ('witti', 'lethal'):1.0
# ('lethal', 'gimmick'):1.0
# ('gimmick', 'morbid'):1.0
# ('morbid', 'joke'):1.0
# ('joke', 'anarchist'):0.006896551724137931
# ('anarchist', 'isn'):1.0
# ('isn', 'crimin'):0.14285714285714285
# ('crimin', 'master'):0.25
# ('master', 'he'):0.3333333333333333
# ('he', 'lower'):0.1
# ('lower', 'goe'):0.5
# ('goe', 'school'):0.25
# ('school', 'shorter'):0.5
# ('shorter', 'streak'):1.0
# ('streak', 'secondli'):1.0
# ('secondli', 'said'):0.5
# ('said', 'earlier'):0.2
# ('earlier', 'film'):1.0
# ('ill', 'monkey'):0.034482758620689655
# ('monkey', 'wash'):1.0
# ('wash', 'increas'):1.0
# ('increas', 'awar'):1.0
# ('awar', 'mental'):1.0
# ('health', 'one'):0.14285714285714285
# ('one', 'concept'):0.019230769230769232
# ('concept', 'sycosi'):1.0
# ('sycosi', 'mental'):1.0
# ('health', 'problem'):0.14285714285714285
# ('problem', 'judici'):0.125
# ('judici', 'explor'):1.0
# ('explor', 'movi'):1.0
# ('movi', 'ill'):0.004807692307692308
# ('ill', 'caus'):0.034482758620689655
# ('caus', 'suffer'):0.16666666666666666
# ('suffer', 'laugh'):0.25
# ('laugh', 'inappropri'):0.05555555555555555
# ('inappropri', 'situat'):0.5
# ('situat', 'serious'):0.3333333333333333
# ('serious', 'your'):0.2
# ('your', 'get'):0.25
# ('get', 'downtrodden'):0.02631578947368421
# ('downtrodden', 'longer'):1.0
# ('longer', 'subject'):0.5
# ('subject', 'beat'):0.5
# ('beat', 'injustic'):1.0
# ('injustic', 'design'):0.5
# ('design', 'spark'):0.3333333333333333
# ('spark', 'indign'):1.0
# ('indign', 'viewer'):1.0
# ('viewer', 'go'):0.25
# ('go', 'murder'):0.0625
# ('murder', 'spree'):0.25
# ('spree', 'regard'):1.0
# ('regard', 'muchprais'):0.5
# ('muchprais', 'act'):1.0
# ('act', 'mysteri'):0.02564102564102564
# ('mysteri', 'anyon'):1.0
# ('could', 'come'):0.05
# ('come', 'judgement'):0.0625
# ('judgement', 'phoenix'):1.0
# ('phoenix', 'theatric'):0.013513513513513514
# ('theatric', 'achiev'):0.3333333333333333
# ('achiev', 'base'):0.5
# ('base', 'quinin'):0.2
# ('quinin', 'script'):1.0
# ('script', 'can'):0.25
# ('can', 'devot'):0.1111111111111111
# ('devot', 'iota'):1.0
# ('iota', 'attent'):1.0
# ('attent', 'posit'):0.16666666666666666
# ('posit', 'review'):0.5
# ('review', 'in'):0.04
# ('in', 'fairli'):0.125
# ('fairli', 'confid'):0.5
# ('confid', 'largescal'):0.3333333333333333
# ('largescal', 'review'):1.0
# ('review', 'rig'):0.04
# ('rig', 'go'):1.0
# ('go', 'plot'):0.0625
# ('plot', 'one'):0.08695652173913043
# ('one', 'dimens'):0.038461538461538464
# ('dimens', 'juvenil'):0.5
# ('juvenil', 'dialogu'):1.0
# ('dialogu', 'engag'):0.25
# ('engag', 'monotoni'):0.2
# ('monotoni', 'nurseri'):1.0
# ('nurseri', 'rhyme'):1.0
# ('rhyme', 'charact'):0.5
# ('develop', 'shallow'):0.14285714285714285
# ('shallow', 'good'):0.5
# ('good', 'left'):0.018867924528301886
# ('left', 'right'):0.125
# ('right', 'centr'):0.07692307692307693
# ('centr', 'like'):1.0
# ('like', 'revolv'):0.017241379310344827
# ('revolv', 'zero'):0.2
# ('zero', 'recoil'):0.5
# ('recoil', '8'):1.0
# ('8', 'bullet'):0.3333333333333333
# ('bullet', 'arthur'):1.0
# ('arthur', 'keep'):0.027777777777777776
# ('keep', 'danc'):0.1111111111111111
# ('danc', 'need'):0.16666666666666666
# ('need', 'see'):0.041666666666666664
# ('see', 'arthur'):0.03333333333333333
# ('arthur', 'foundl'):0.027777777777777776
# ('foundl', 'emaci'):1.0
# ('emaci', 'much'):1.0
# ('much', 'smoke'):0.034482758620689655
# ('smoke', 'watch'):0.3333333333333333
# ('mani', 'close'):0.029411764705882353
# ('close', 'cigarett'):0.16666666666666666
# ('cigarett', 'burn'):0.5
# ('burn', 'make'):1.0
# ('make', 'wonder'):0.029411764705882353
# ('wonder', 'film'):0.2
# ('film', 'sponsor'):0.008620689655172414
# ('sponsor', 'tobacco'):1.0
# ('tobacco', 'industri'):1.0
# ('industri', 'two'):1.0
# ('two', 'posit'):0.1111111111111111
# ('posit', 'movi'):0.5
# ('movi', 'firstli'):0.004807692307692308
# ('firstli', 'final'):0.5
# ('final', 'talk'):0.16666666666666666
# ('talk', 'show'):0.42857142857142855
# ('show', 'scene'):0.05555555555555555
# ('scene', 'litter'):0.043478260869565216
# ('litter', 'though'):1.0
# ('though', 'imperfect'):0.09090909090909091
# ('imperfect', 'like'):1.0
# ('like', 'rest'):0.017241379310344827
# ('rest', 'movi'):0.6666666666666666
# ('movi', 'sit'):0.004807692307692308
# ('sit', 'littl'):0.3333333333333333
# ('littl', 'le'):0.1
# ('le', 'slough'):0.125
# ('slough', 'seat'):1.0
# ('seat', 'also'):0.2
# ('also', 'interest'):0.09090909090909091
# ('interest', 'theori'):0.14285714285714285
# ('theori', 'present'):1.0
# ('present', 'tie'):0.1111111111111111
# ('tie', 'joke'):0.25
# ('joke', 'batman'):0.006896551724137931
# ('batman', 'bar'):0.047619047619047616
# ('bar', 'set'):0.3333333333333333
# ('set', 'high'):0.14285714285714285
# ('high', 'dark'):0.07692307692307693
# ('knight', 'director'):0.09090909090909091
# ('director', 'seek'):0.1
# ('seek', 'artist'):1.0
# ('artist', 'claim'):0.5
# ('claim', 'go'):0.25
# ('go', 'near'):0.0625
# ('near', 'joke'):0.3333333333333333
# ('joke', 'mani'):0.006896551724137931
# ('mani', 'year'):0.029411764705882353
# ('year', 'come'):0.041666666666666664
# ('come', 'mayb'):0.0625
# ('mayb', 'ever'):0.14285714285714285
# ('ever', 'hand'):0.07142857142857142
# ('hand', 'joke'):0.14285714285714285
# ('charact', 'render'):0.017857142857142856
# ('render', 'boon'):1.0
# ('boon', 'hollywood'):1.0
# ('hollywood', 'opportun'):0.14285714285714285
# ('opportun', 'second'):0.5
# ('second', 'time'):0.6666666666666666
# ('time', 'were'):0.021739130434782608
# ('were', 'seen'):1.0
# ('seen', 'charact'):0.041666666666666664
# ('charact', 'butcher'):0.017857142857142856
# ('butcher', 'low'):1.0
# ('low', 'effort'):0.3333333333333333
# ('effort', 'high'):0.5
# ('high', 'budget'):0.07692307692307693
# ('budget', 'money'):1.0
# ('money', 'maker'):0.14285714285714285
# ('maker', 'one'):1.0
# ('one', 'forgotten'):0.019230769230769232
# ('forgotten', 'quick'):1.0
# ('quick', 'dont'):1.0
# ('dont', 'know'):0.0625
# ('know', 'long'):0.047619047619047616
# ('long', 'joke'):0.125
# ('joke', 'recov'):0.006896551724137931
# ('recov', 'dont'):1.0
# ('understand', 'high'):0.06666666666666667
# ('high', 'rate'):0.15384615384615385
# ('rate', 'went'):0.09090909090909091
# ('went', 'cinema'):0.09090909090909091
# ('cinema', 'high'):0.07692307692307693
# ('high', 'expect'):0.07692307692307693
# ('expect', 'discov'):0.05
# ('discov', 'movi'):1.0
# ('slow', 'anyth'):0.07142857142857142
# ('anyth', 'almost'):0.1111111111111111
# ('almost', 'finish'):0.16666666666666666
# ('finish', 'first'):0.25
# ('first', 'kill'):0.0625
# ('kill', 'happen'):0.16666666666666666
# ('happen', 'dread'):0.0625
# ('dread', 'time'):1.0
# ('time', 'wait'):0.021739130434782608
# ('wait', 'someth'):0.3333333333333333
# ('someth', 'happen'):0.0625
# ('happen', 'ye'):0.0625
# ('movi', 'finish'):0.004807692307692308
# ('finish', 'final'):0.25
# ('final', 'walk'):0.16666666666666666
# ('walk', 'got'):0.25
# ('got', 'comic'):0.2
# ('comic', 'joke'):0.047619047619047616
# ('joke', 'trust'):0.006896551724137931
# ('trust', 'review'):1.0
# ('review', 'leav'):0.04
# ('leav', 'disappoint'):0.1111111111111111
# ('disappoint', 'disbeliev'):0.3333333333333333
# ('disbeliev', 'actual'):1.0
# ('actual', 'paid'):0.058823529411764705
# ('paid', 'watch'):0.5
# ('watch', 'incred'):0.021739130434782608
# ('incred', 'ride'):0.09090909090909091
# ('ride', 'almost'):0.3333333333333333
# ('almost', 'motionless'):0.16666666666666666
# ('motionless', 'throughout'):1.0
# ('throughout', 'watch'):0.1
# ('watch', 'awe'):0.021739130434782608
# ('awe', 'perform'):1.0
# ('lifetim', 'transit'):0.3333333333333333
# ('transit', 'troubl'):0.3333333333333333
# ('troubl', 'man'):0.5
# ('man', 'monster'):0.08333333333333333
# ('monster', 'found'):0.3333333333333333
# ('found', 'score'):0.25
# ('score', 'directli'):0.05
# ('directli', 'drove'):0.5
# ('drove', 'goosebump'):1.0
# ('goosebump', 'cinematographi'):1.0
# ('cinematographi', 'made'):0.043478260869565216
# ('like', 'fli'):0.017241379310344827
# ('fli', 'gothic'):1.0
# ('gothic', 'look'):0.14285714285714285
# ('look', 'arthur'):0.0625
# ('arthur', 'wast'):0.027777777777777776
# ('wast', 'de'):0.14285714285714285
# ('de', 'no'):0.8571428571428571
# ('no', 'gave'):0.14285714285714285
# ('gave', 'nod'):0.3333333333333333
# ('nod', 'merri'):0.5
# ('merri', 'lewi'):1.0
# ('lewi', 'ignor'):1.0
# ('ignor', 'do'):0.25
# ('do', 'ignor'):0.058823529411764705
# ('ignor', 'batman'):0.25
# ('batman', 'work'):0.047619047619047616
# ('work', 'art'):0.07142857142857142
# ('art', 'right'):0.1111111111111111
# ('right', 'origin'):0.07692307692307693
# ('origin', 'monster'):0.0625
# ('monster', 'see'):0.3333333333333333
# ('see', 'one'):0.06666666666666667
# ('one', 'film'):0.019230769230769232
# ('year', 'plea'):0.041666666666666664
# ('plea', 'see'):0.16666666666666666
# ('see', 'joke'):0.06666666666666667
# ('joke', 'seem'):0.013793103448275862
# ('seem', 'get'):0.06666666666666667
# ('get', 'constant'):0.02631578947368421
# ('constant', 'remark'):0.5
# ('remark', 'origin'):0.3333333333333333
# ('film', 'remark'):0.008620689655172414
# ('remark', 'think'):0.3333333333333333
# ('think', 'peopl'):0.037037037037037035
# ('peopl', 'fed'):0.02564102564102564
# ('fed', 'mention'):0.5
# ('mention', 'categori'):0.5
# ('categori', 'mani'):0.25
# ('move', 'present'):0.02702702702702703
# ('present', 'haven'):0.1111111111111111
# ('haven', 'come'):0.5
# ('come', 'scratch'):0.0625
# ('scratch', 'joke'):1.0
# ('joke', 'howev'):0.006896551724137931
# ('howev', 'phenomenon'):0.16666666666666666
# ('phenomenon', 'best'):0.2
# ('film', 'give'):0.02586206896551724
# ('give', 'seen'):0.18181818181818182
# ('seen', 'cinema'):0.041666666666666664
# ('cinema', 'quit'):0.07692307692307693
# ('quit', 'time'):0.18181818181818182
# ('time', 'enthral'):0.021739130434782608
# ('enthral', 'start'):1.0
# ('start', 'finish'):0.1
# ('finish', 'stori'):0.25
# ('stori', 'fantast'):0.02631578947368421
# ('fantast', 'write'):0.5
# ('write', 'thought'):0.1
# ('thought', 'intellig'):0.07142857142857142
# ('intellig', 'joaquin'):0.2
# ('phoenix', 'say'):0.013513513513513514
# ('say', 'master'):0.02564102564102564
# ('master', 'class'):0.3333333333333333
# ('class', 'perform'):0.14285714285714285
# ('perform', 'insect'):0.022727272727272728
# ('insect', 'everyth'):1.0
# ('everyth', 'need'):0.1111111111111111
# ('need', 'part'):0.041666666666666664
# ('part', 'make'):0.14285714285714285
# ('make', 'shill'):0.029411764705882353
# ('shill', 'sad'):0.5
# ('sad', 'menac'):0.16666666666666666
# ('menac', 'wonder'):1.0
# ('wonder', 'award'):0.2
# ('award', 'flow'):0.2
# ('flow', 'genuin'):0.3333333333333333
# ('genuin', 'can'):0.3333333333333333
# ('not', 'rememb'):0.25
# ('rememb', 'last'):0.2
# ('last', 'time'):0.1111111111111111
# ('time', 'left'):0.021739130434782608
# ('left', 'cinema'):0.25
# ('cinema', 'feel'):0.07692307692307693
# ('feel', 'reward'):0.02631578947368421
# ('reward', 'film'):1.0
# ('incred', '1010'):0.09090909090909091
# ('1010', 'movi'):0.2
# ('movi', 'masterpiec'):0.004807692307692308
# ('masterpiec', 'absolut'):0.047619047619047616
# ('absolut', 'epitom'):0.08333333333333333
# ('epitom', 'do'):1.0
# ('do', 'movi'):0.058823529411764705
# ('movi', 'dark'):0.014423076923076924
# ('dark', 'emot'):0.03125
# ('emot', 'thought'):0.08333333333333333
# ('thought', 'provok'):0.07142857142857142
# ('provok', 'action'):1.0
# ('action', 'action'):0.1111111111111111
# ('action', 'one'):0.05555555555555555
# ('move', 'give'):0.05405405405405406
# ('seen', 'long'):0.041666666666666664
# ('time', 'critic'):0.021739130434782608
# ('critic', 'definit'):0.09090909090909091
# ('definit', 'lost'):0.07692307692307693
# ('lost', 'touch'):1.0
# ('touch', 'public'):0.3333333333333333
# ('public', 'ignor'):0.5
# ('ignor', 'one'):0.25
# ('one', 'favor'):0.019230769230769232
# ('favor', 'watch'):0.5
# ('watch', 'rememb'):0.021739130434782608
# ('rememb', 'good'):0.2
# ('good', 'one'):0.03773584905660377
# ('one', 'anoth'):0.019230769230769232
# ('anoth', 'dont'):0.2
# ('know', 'someon'):0.047619047619047616
# ('someon', 'el'):0.2
# ('el', 'go'):0.3333333333333333
# ('go', 'never'):0.0625
# ('never', 'left'):0.09090909090909091
# ('left', 'review'):0.125
# ('review', 'titl'):0.08
# ('titl', 'good'):0.14285714285714285
# ('bad', 'piec'):0.05555555555555555
# ('piec', 'garag'):0.25
# ('garag', 'regist'):0.2
# ('regist', 'limb'):1.0
# ('limb', 'account'):1.0
# ('account', 'vent'):1.0
# ('vent', 'opinion'):1.0
# ('opinion', 'want'):0.14285714285714285
# ('want', '2'):0.05
# ('hour', 'life'):0.2
# ('life', 'back'):0.08333333333333333
# ('back', 'writerdirector'):0.14285714285714285
# ('writerdirector', 'told'):1.0
# ('phillip', 'new'):0.06666666666666667
# ('new', 'movi'):0.08333333333333333
# ('joke', 'appeal'):0.006896551724137931
# ('appeal', 'multipl'):1.0
# ('multipl', 'level'):0.2
# ('level', 'primarili'):0.3333333333333333
# ('primarili', 'offer'):1.0
# ('offer', 'engag'):0.3333333333333333
# ('engag', 'stori'):0.2
# ('stori', 'strongli'):0.02631578947368421
# ('strongli', 'root'):1.0
# ('root', 'believ'):0.25
# ('believ', 'realiti'):0.125
# ('realiti', 'relat'):0.16666666666666666
# ('relat', 'audienc'):0.14285714285714285
# ('audienc', 'mainli'):0.2
# ('mainli', 'oppos'):1.0
# ('oppos', 'protagonist'):0.5
# ('protagonist', 'preval'):1.0
# ('preval', 'dark'):1.0
# ('dark', 'depress'):0.09375
# ('depress', 'mood'):0.25
# ('mood', 'use'):0.5
# ('use', 'often'):0.16666666666666666
# ('often', 'optimist'):0.3333333333333333
# ('optimist', 'soundtrack'):1.0
# ('soundtrack', 'sound'):0.25
# ('sound', 'edit'):0.25
# ('edit', 'shallow'):0.3333333333333333
# ('shallow', 'nonetheless'):0.5
# ('nonetheless', 'rich'):1.0
# ('rich', 'visual'):0.25
# ('visual', 'angl'):0.5
# ('angl', 'frame'):0.25
# ('frame', 'theatric'):0.5
# ('theatric', 'augment'):0.3333333333333333
# ('augment', 'express'):1.0
# ('express', 'costum'):0.3333333333333333
# ('costum', 'drop'):0.5
# ('drop', 'set'):0.3333333333333333
# ('set', 'impress'):0.14285714285714285
# ('impress', 'via'):0.3333333333333333
# ('via', 'great'):1.0
# ('great', 'princip'):0.02857142857142857
# ('princip', 'perform'):1.0
# ('perform', 'act'):0.022727272727272728
# ('act', 'choic'):0.02564102564102564
# ('made', 'joaquin'):0.045454545454545456
# ('phoenix', 'lead'):0.02702702702702703
# ('lead', 'titl'):0.3333333333333333
# ('titl', 'charact'):0.14285714285714285
# ('charact', 'proper'):0.017857142857142856
# ('proper', 'section'):0.2
# ('section', 'name'):0.5
# ('name', 'arthur'):0.25
# ('fleck', 'whose'):0.08333333333333333
# ('whose', 'sudden'):0.25
# ('sudden', 'uncontrol'):1.0
# ('uncontrol', 'seemingli'):0.5
# ('seemingli', 'inappropri'):1.0
# ('inappropri', 'laughter'):0.5
# ('laughter', 'justifi'):1.0
# ('justifi', 'medic'):0.25
# ('medic', 'condit'):1.0
# ('condit', 'easili'):1.0
# ('easili', 'counterpoint'):0.25
# ('counterpoint', 'pain'):1.0
# ('pain', 'need'):0.16666666666666666
# ('need', 'outcri'):0.041666666666666664
# ('outcri', 'gothic'):1.0
# ('gothic', 'read'):0.14285714285714285
# ('read', 'citi'):0.25
# ('citi', 'mass'):0.2
# ('mass', 'hurt'):0.3333333333333333
# ('hurt', 'depriv'):0.5
# ('depriv', 'injustic'):1.0
# ('injustic', 'quotidian'):0.5
# ('quotidian', 'exist'):1.0
# ('exist', 'well'):0.3333333333333333
# ('well', 'robert'):0.06666666666666667
# ('robert', 'de'):1.0
# ('no', 'quintessenti'):0.14285714285714285
# ('quintessenti', 'support'):1.0
# ('support', 'role'):0.25
# ('role', 'comedi'):0.09090909090909091
# ('comedi', 'show'):0.14285714285714285
# ('show', 'host'):0.1111111111111111
# ('host', 'murray'):1.0
# ('murray', 'franklin'):0.6666666666666666
# ('franklin', 'worthi'):0.25
# ('worthi', 'endoftheyear'):0.25
# ('endoftheyear', 'act'):1.0
# ('act', 'award'):0.02564102564102564
# ('award', 'consider'):0.2
# ('consider', 'set'):1.0
# ('set', 'believ'):0.14285714285714285
# ('believ', 'recours'):0.125
# ('recours', 'futur'):1.0
# ('futur', 'adventur'):0.3333333333333333
# ('adventur', 'realist'):1.0
# ('realist', 'do'):0.16666666666666666
# ('comic', 'charact'):0.047619047619047616
# ('charact', 'batman'):0.017857142857142856
# ('batman', 'superhero'):0.047619047619047616
# ('superhero', 'extraordinari'):0.07692307692307693
# ('extraordinari', 'capabl'):0.5
# ('capabl', 'rather'):1.0
# ('rather', 'result'):0.3333333333333333
# ('result', 'physic'):1.0
# ('physic', 'fit'):0.25
# ('fit', 'skill'):1.0
# ('skill', 'combin'):1.0
# ('combin', 'high'):0.5
# ('high', 'technolog'):0.07692307692307693
# ('technolog', 'employ'):1.0
# ('employ', 'appear'):1.0
# ('appear', 'young'):0.5
# ('young', 'boy'):1.0
# ('boy', 'whose'):0.2
# ('whose', 'later'):0.25
# ('later', 'adult'):0.3333333333333333
# ('adult', 'activ'):0.5
# ('activ', 'could'):1.0
# ('could', 'understood'):0.05
# ('understood', 'larg'):1.0
# ('larg', 'driven'):1.0
# ('driven', 'happen'):1.0
# ('happen', 'parent'):0.0625
# ('parent', 'final'):1.0
# ('final', 'scene'):0.16666666666666666
# ('scene', 'movi'):0.043478260869565216
# ('movi', 'event'):0.004807692307692308
# ('event', 'directli'):0.5
# ('directli', 'inspir'):0.5
# ('inspir', 'action'):0.125
# ('joke', 'henceforth'):0.006896551724137931
# ('henceforth', 'futur'):1.0
# ('futur', 'main'):0.3333333333333333
# ('main', 'nemes'):0.14285714285714285
# ('nemes', 'joke'):1.0
# ('joke', 'liter'):0.006896551724137931
# ('liter', 'achiev'):0.5
# ('achiev', 'cinemat'):0.5
# ('cinemat', 'histori'):0.3333333333333333
# ('histori', 'there'):0.3333333333333333
# ('there', 'doubt'):0.14285714285714285
# ('doubt', 'peopl'):0.2
# ('peopl', 'compar'):0.02564102564102564
# ('compar', 'engag'):0.2
# ('engag', 'move'):0.2
# ('move', 'way'):0.02702702702702703
# ('way', 'complet'):0.029411764705882353
# ('differ', 'engag'):0.06666666666666667
# ('engag', 'best'):0.2
# ('best', 'gene'):0.029411764705882353
# ('gene', 'talk'):0.125
# ('talk', 'joke'):0.14285714285714285
# ('joke', 'say'):0.013793103448275862
# ('say', 'beauti'):0.02564102564102564
# ('beauti', 'present'):0.25
# ('present', 'storylin'):0.1111111111111111
# ('storylin', 'direct'):0.2
# ('direct', 'screenplay'):0.14285714285714285
# ('screenplay', 'peak'):0.16666666666666666
# ('peak', 'great'):1.0
# ('great', 'heath'):0.05714285714285714
# ('ledger', 'smile'):0.05
# ('smile', 'earth'):0.5
# ('earth', 'in'):1.0
# ('in', 'keep'):0.125
# ('keep', 'short'):0.1111111111111111
# ('short', 'movi'):0.16666666666666666
# ('movi', 'suck'):0.004807692307692308
# ('suck', 'ye'):0.5
# ('ye', 'know'):0.1111111111111111
# ('know', 'there'):0.047619047619047616
# ('there', 'need'):0.14285714285714285
# ('need', 'build'):0.041666666666666664
# ('build', 'charact'):0.1
# ('charact', 'cap'):0.017857142857142856
# ('cap', 'think'):0.5
# ('think', 'import'):0.037037037037037035
# ('import', 'good'):0.1111111111111111
# ('movi', 'goe'):0.004807692307692308
# ('goe', 'get'):0.25
# ('get', 'joke'):0.02631578947368421
# ('joke', 'troubl'):0.006896551724137931
# ('man', 'get'):0.08333333333333333
# ('get', 'frustrat'):0.02631578947368421
# ('frustrat', 'dont'):0.5
# ('dont', 'need'):0.0625
# ('need', '2'):0.041666666666666664
# ('hour', 'movi'):0.1
# ('movi', 'tell'):0.004807692307692308
# ('tell', 'cap'):0.2
# ('cap', 'give'):0.5
# ('give', 'guy'):0.045454545454545456
# ('guy', 'oscar'):0.25
# ('oscar', 'perform'):0.05555555555555555
# ('perform', 'throw'):0.022727272727272728
# ('throw', 'movi'):0.5
# ('movi', 'trash'):0.004807692307692308
# ('trash', 'right'):0.3333333333333333
# ('right', 'right'):0.07692307692307693
# ('right', 'prais'):0.07692307692307693
# ('prais', 'hope'):0.25
# ('hope', '2019'):0.05
# ('2019', 'movi'):0.25
# ('joke', 'director'):0.006896551724137931
# ('director', 'told'):0.4
# ('phillip', 'get'):0.06666666666666667
# ('get', 'much'):0.02631578947368421
# ('movi', 'you'):0.004807692307692308
# ('you', 'eventu'):0.2
# ('eventu', 'find'):0.3333333333333333
# ('find', 'way'):0.125
# ('way', 'watch'):0.029411764705882353
# ('watch', 'let'):0.021739130434782608
# ('say', 'expect'):0.02564102564102564
# ...
# ('year', 'hollywood'):0.041666666666666664
# ('hollywood', 'actor'):0.14285714285714285
# ('actor', 'applaus'):0.058823529411764705
# ('applaus', 'play'):0.25
# ('play', 'villain'):0.14285714285714285
# ('villain', 'easiest'):0.09090909090909091
# ('easiest', 'charact'):1.0
# ('studi', 'what'):0.2
# ('what', 'hard'):0.3333333333333333
# ('hard', 'protector'):0.1111111111111111
# ('protector', 'realm'):1.0
# ('realm', 'without'):1.0
# ('without', 'feel'):0.07142857142857142
# ('feel', 'preach'):0.02631578947368421
# ('preach', 'chees'):1.0
# ('chees', 'role'):1.0
# ('role', 'get'):0.09090909090909091
# ('get', 'natur'):0.02631578947368421
# ('natur', 'upscal'):0.25
# ('upscal', 'main'):1.0
# ('main', 'plot'):0.14285714285714285
# ('plot', 'element'):0.043478260869565216
# ('element', 'invit'):0.25
# ('invit', 'arthur'):1.0
# ('arthur', 'onto'):0.027777777777777776
# ('onto', 'talk'):1.0
# ('show', 'convinc'):0.05555555555555555
# ('convinc', 'stand'):0.16666666666666666
# ('stand', 'perform'):0.25
# ('perform', 'gene'):0.022727272727272728
# ('gene', 'bad'):0.125
# ('bad', 'good'):0.05555555555555555
# ('good', 'first'):0.018867924528301886
# ('first', 'vision'):0.0625
# ('vision', 'audienc'):0.5
# ('audienc', 'defend'):0.2
# ('defend', 'mother'):1.0
# ('mother', 'howev'):0.25
# ('howev', 'power'):0.16666666666666666
# ('power', 'well'):0.3333333333333333
# ('well', 'written'):0.06666666666666667
# ('written', 'cameo'):0.3333333333333333
# ('cameo', 'alfr'):1.0
# ('alfr', 'butler'):1.0
# ('butler', 'would'):1.0
# ('would', 'special'):0.037037037037037035
# ('special', 'realli'):0.5
# ('realli', 'pull'):0.029411764705882353
# ('pull', 'u'):0.2
# ('u', 'back'):0.06666666666666667
# ('back', 'stori'):0.14285714285714285
# ('stori', 'way'):0.02631578947368421
# ('film', 'land'):0.008620689655172414
# ('land', 'first'):1.0
# ('first', 'week'):0.0625
# ('week', 'ridicul'):0.5
# ('ridicul', 'drag'):1.0
# ('drag', 'mani'):0.25
# ('mani', 'place'):0.029411764705882353
# ('place', 'the'):0.3333333333333333
# ('the', 'hour'):1.0
# ('hour', 'screen'):0.1
# ('screen', 'theatric'):0.16666666666666666
# ('theatric', 'trailer'):0.3333333333333333
# ('trailer', '8'):0.14285714285714285
# ('8', 'mani'):0.3333333333333333
# ('mani', 'u'):0.029411764705882353
# ('u', 'expect'):0.06666666666666667
# ('expect', 'say'):0.05
# ('better', 'product'):0.047619047619047616
# ('product', 'batman'):0.3333333333333333
# ('begin', 'shock'):0.1
# ('shock', 'difficult'):0.25
# ('difficult', 'realiti'):0.25
# ('realiti', 'bare'):0.16666666666666666
# ('bare', 'hope'):0.5
# ('hope', 'rate'):0.05
# ('rate', 'cultur'):0.09090909090909091
# ('cultur', 'realiti'):1.0
# ('realiti', 'mani'):0.16666666666666666
# ('peopl', 'age'):0.02564102564102564
# ('age', 'realli'):1.0
# ('realli', 'feel'):0.029411764705882353
# ('like', 'verg'):0.017241379310344827
# ('verg', 'riot'):1.0
# ('riot', 'life'):0.5
# ('life', 'take'):0.08333333333333333
# ('take', 'toll'):0.04
# ('toll', 'broken'):1.0
# ('broken', 'man'):0.25
# ('man', 'whose'):0.08333333333333333
# ('whose', 'mental'):0.25
# ('inabl', 'ill'):0.5
# ('ill', 'cataclysm'):0.034482758620689655
# ('cataclysm', 'arthur'):1.0
# ('fleck', 'eventu'):0.08333333333333333
# ('eventu', 'becom'):0.3333333333333333
# ('becom', 'great'):0.09090909090909091
# ('stori', 'told'):0.02631578947368421
# ('told', 'million'):0.05555555555555555
# ('million', 'way'):1.0
# ('way', 'execut'):0.029411764705882353
# ('execut', 'well'):0.25
# ('well', 'dream'):0.06666666666666667
# ('dream', 'sequenc'):0.5
# ('sequenc', 'work'):1.0
# ('work', 'well'):0.07142857142857142
# ('well', 'devic'):0.06666666666666667
# ('devic', 'still'):1.0
# ('still', 'good'):0.16666666666666666
# ('good', 'heath'):0.018867924528301886
# ('ledger', 'raw'):0.05
# ('raw', 'portray'):1.0
# ('portray', 'psychopath'):0.06666666666666667
# ('psychopath', 'megalomaniac'):0.3333333333333333
# ('megalomaniac', 'cinematographi'):1.0
# ('cinematographi', 'woman'):0.043478260869565216
# ('woman', 'relat'):0.5
# ('relat', 'film'):0.14285714285714285
# ('film', 'simpl'):0.008620689655172414
# ('simpl', 'plot'):1.0
# ('plot', 'failur'):0.043478260869565216
# ('failur', 'like'):0.5
# ('like', 'polic'):0.017241379310344827
# ('polic', 'abl'):0.5
# ('abl', 'catch'):0.2
# ('catch', 'arthur'):1.0
# ('arthur', 'tri'):0.027777777777777776
# ('tri', 'care'):0.058823529411764705
# ('care', 'disappoint'):0.2
# ('disappoint', 'took'):0.3333333333333333
# ('took', 'right'):0.2
# ('right', 'stori'):0.07692307692307693
# ('stori', 'good'):0.02631578947368421
# ('good', 'resembl'):0.018867924528301886
# ('resembl', 'actor'):1.0
# ('actor', 'can'):0.058823529411764705
# ('can', 'save'):0.1111111111111111
# ('save', 'bad'):0.3333333333333333
# ('bad', 'script'):0.05555555555555555
# ('script', 'rush'):0.25
# ('rush', 'product'):0.5
# ('product', 'someth'):0.3333333333333333
# ('someth', 'import'):0.0625
# ('import', 'batman'):0.1111111111111111
# ('batman', 'origin'):0.047619047619047616
# ('stori', 'need'):0.02631578947368421
# ('need', 'much'):0.041666666666666664
# ('much', 'care'):0.034482758620689655
# ('care', 'work'):0.2
# ('work', 'believ'):0.07142857142857142
# ('believ', 'time'):0.125
# ('score', 'must'):0.05
# ('must', 'averag'):0.25
# ('averag', 'homag'):0.16666666666666666
# ('homag', 'taxi'):1.0
# ('comedi', 'appar'):0.14285714285714285
# ('appar', 'opportun'):1.0
# ('opportun', 'genuin'):0.5
# ('genuin', 'franchis'):0.3333333333333333
# ('franchis', 'build'):0.3333333333333333
# ('build', 'surprisingli'):0.1
# ('surprisingli', 'toss'):1.0
# ('toss', 'away'):0.5
# ('away', 'hard'):0.1111111111111111
# ('hard', 'repair'):0.1111111111111111
# ('repair', 'critic'):1.0
# ('critic', 'use'):0.09090909090909091
# ('use', 'word'):0.16666666666666666
# ('word', 'masterpiec'):0.25
# ('groundbreak', 'need'):0.3333333333333333
# ('need', 'long'):0.041666666666666664
# ('long', 'hard'):0.125
# ('hard', 'look'):0.1111111111111111
# ('look', 'surround'):0.0625
# ('surround', 'educ'):0.3333333333333333
# ('educ', 'seem'):1.0
# ('seem', 'share'):0.06666666666666667
# ('share', 'f'):1.0
# ('f', 'diver'):1.0
# ('diver', 'mob'):1.0
# ('mob', 'keep'):1.0
# ('keep', 'play'):0.1111111111111111
# ('play', 'u'):0.14285714285714285
# ('u', 'best'):0.06666666666666667
# ('act', 'stori'):0.02564102564102564
# ('stori', 'oscar'):0.02631578947368421
# ('win', 'movi'):0.1111111111111111
# ('film', 'surpass'):0.008620689655172414
# ('surpass', 'film'):1.0
# ('film', 'portray'):0.008620689655172414
# ('portray', 'slow'):0.06666666666666667
# ('slow', 'descent'):0.07142857142857142
# ('mad', 'caus'):0.14285714285714285
# ('caus', 'biolog'):0.16666666666666666
# ('biolog', 'psycholog'):0.5
# ('psycholog', 'social'):0.1
# ('social', 'familiar'):0.16666666666666666
# ('familiar', 'factor'):1.0
# ('factor', 'also'):0.5
# ('also', 'highlight'):0.045454545454545456
# ('highlight', 'decay'):0.5
# ('decay', 'n'):1.0
# ('n', 'broken'):0.2
# ('broken', 'system'):0.25
# ('system', 'n'):0.5
# ('n', 'societi'):0.2
# ('societi', 'auster'):0.045454545454545456
# ('auster', 'film'):1.0
# ('dark', 'amaz'):0.03125
# ('amaz', 'cinematographi'):0.07142857142857142
# ('cinematographi', 'n'):0.043478260869565216
# ('n', 'year'):0.2
# ('year', 'best'):0.041666666666666664
# ('perform', 'phoenix'):0.022727272727272728
# ('phoenix', 'surrealist'):0.013513513513513514
# ('surrealist', 'feel'):1.0
# ('feel', 'n'):0.02631578947368421
# ('n', 'fact'):0.2
# ('fact', 'solid'):0.2
# ('solid', 'non'):1.0
# ('non', 'horror'):1.0
# ('horror', 'film'):0.25
# ('film', 'terrifi'):0.008620689655172414
# ('terrifi', 'n'):0.3333333333333333
# ('n', 'poignant'):0.2
# ('poignant', 'confus'):1.0
# ('confus', 'represent'):0.16666666666666666
# ('represent', 'insan'):1.0
# ('insan', 'perspect'):0.1
# ('perspect', 'sane'):0.5
# ('person', 'celebr'):0.0625
# ('celebr', 'mad'):1.0
# ('mad', 'chao'):0.14285714285714285
# ('chao', 'last'):0.3333333333333333
# ('last', 'watch'):0.1111111111111111
# ('one', 'anticip'):0.019230769230769232
# ('anticip', 'move'):0.5
# ('year', 'experienc'):0.041666666666666664
# ('experienc', 'sad'):0.3333333333333333
# ('sad', 'greedi'):0.16666666666666666
# ('greedi', 'joy'):1.0
# ('joy', 'rage'):1.0
# ('rage', 'confus'):1.0
# ('confus', 'altogeth'):0.16666666666666666
# ('altogeth', 'felt'):1.0
# ('felt', 'good'):0.0625
# ('stori', 'averag'):0.02631578947368421
# ('averag', 'sometim'):0.16666666666666666
# ('sometim', 'director'):0.16666666666666666
# ('director', 'seem'):0.1
# ('seem', 'confus'):0.06666666666666667
# ('confus', 'he'):0.16666666666666666
# ('he', 'tri'):0.1
# ('say', 'mani'):0.02564102564102564
# ('mani', 'beauti'):0.029411764705882353
# ('beauti', 'distinct'):0.25
# ('distinct', 'piec'):0.3333333333333333
# ('piec', 'scatter'):0.25
# ('scatter', 'throughout'):1.0
# ('give', 'chill'):0.045454545454545456
# ('chill', 'ultim'):1.0
# ('ultim', 'fail'):0.5
# ('fail', 'form'):0.2
# ('form', 'complet'):0.25
# ('complet', 'landscap'):0.06666666666666667
# ('landscap', 'eventu'):1.0
# ('eventu', 'becam'):0.3333333333333333
# ('becam', 'gorgeou'):0.5
# ('gorgeou', 'draft'):1.0
# ('draft', 'barqu'):1.0
# ('barqu', 'film'):1.0
# ('film', 'sheer'):0.008620689655172414
# ('sheer', 'hollow'):0.5
# ('hollow', 'insid'):0.3333333333333333
# ('insid', 'critic'):1.0
# ('critic', 'selfcent'):0.09090909090909091
# ('selfcent', 'pretens'):1.0
# ('pretens', 'empti'):1.0
# ('empti', 'le'):0.14285714285714285
# ('le', 'societi'):0.125
# ('societi', 'iron'):0.045454545454545456
# ('iron', 'movi'):0.125
# ('movi', 'fall'):0.004807692307692308
# ('fall', 'sword'):0.16666666666666666
# ('sword', 'welcom'):1.0
# ('welcom', 'to'):1.0
# ('to', 'phillip'):0.5
# ('phillip', 'big'):0.06666666666666667
# ('big', 'boy'):0.3333333333333333
# ('boy', 'club'):0.2
# ('club', 'direct'):0.3333333333333333
# ('direct', 'crafti'):0.07142857142857142
# ('crafti', 'pretti'):1.0
# ('pretti', 'awesom'):0.25
# ('awesom', 'though'):0.3333333333333333
# ('though', 'lack'):0.09090909090909091
# ('lack', 'littl'):0.1111111111111111
# ('littl', 'bit'):0.1
# ('bit', 'origin'):0.125
# ('origin', 'trick'):0.0625
# ('trick', 'arthur'):0.5
# ('arthur', 'illus'):0.027777777777777776
# ('illus', 'seem'):1.0
# ('seem', 'bit'):0.06666666666666667
# ('bit', 'riski'):0.125
# ('riski', 'given'):1.0
# ('given', 'context'):0.25
# ('context', 'never'):0.5
# ('never', 'know'):0.09090909090909091
# ('know', 'sure'):0.047619047619047616
# ('sure', 'arthur'):0.0625
# ('arthur', 'go'):0.027777777777777776
# ('go', 'murray'):0.0625
# ('murray', 'show'):0.16666666666666666
# ('show', 'cinematographi'):0.05555555555555555
# ('cinematographi', 'superb'):0.043478260869565216
# ('superb', 'plenti'):0.5
# ('plenti', 'scene'):1.0
# ('scene', 'that'):0.043478260869565216
# ('that', 'enter'):0.07142857142857142
# ('enter', 'mind'):1.0
# ('mind', 'stay'):0.16666666666666666
# ('stay', 'joaquin'):0.25
# ('phoenix', 'best'):0.013513513513513514
# ('best', 'tri'):0.029411764705882353
# ('hard', 'embodi'):0.1111111111111111
# ('embodi', 'magnanim'):0.3333333333333333
# ('magnanim', 'charact'):1.0
# ('charact', 'joke'):0.017857142857142856
# ('joke', 'pretti'):0.006896551724137931
# ('pretti', 'well'):0.25
# ('well', 'sometim'):0.06666666666666667
# ('sometim', 'felt'):0.3333333333333333
# ('felt', 'tri'):0.0625
# ('hard', 'despit'):0.1111111111111111
# ('despit', 'unfair'):0.14285714285714285
# ('unfair', 'compar'):1.0
# ('compar', 'great'):0.2
# ('ledger', 'must'):0.05
# ('must', 'say'):0.25
# ('say', 'abl'):0.02564102564102564
# ('abl', 'pull'):0.2
# ('pull', 'impress'):0.2
# ('impress', 'take'):0.3333333333333333
# ('joke', 'distinct'):0.006896551724137931
# ('distinct', 'level'):0.3333333333333333
# ('level', 'ocean'):0.3333333333333333
# ('ocean', 'show'):1.0
# ('show', 'he'):0.05555555555555555
# ('he', 'donna'):0.1
# ('donna', 'get'):1.0
# ('get', 'nomin'):0.02631578947368421
# ('nomin', 'academi'):0.2
# ('academi', 'award'):1.0
# ('award', 'sure'):0.2
# ('sure', 'one'):0.0625
# ('one', 'entertain'):0.019230769230769232
# ('entertain', 'satisfi'):0.1111111111111111
# ('satisfi', 'aspect'):0.2
# ('aspect', 'film'):0.3333333333333333
# ('film', 'music'):0.008620689655172414
# ('music', 'composit'):0.09090909090909091
# ('composit', 'damn'):1.0
# ('damn', 'good'):0.25
# ('good', 'you'):0.018867924528301886
# ('you', 'get'):0.2
# ('see', 'insan'):0.03333333333333333
# ('insan', 'danc'):0.1
# ('danc', 'move'):0.16666666666666666
# ('move', 'bonu'):0.02702702702702703
# ('bonu', 'main'):1.0
# ('main', 'problem'):0.14285714285714285
# ('problem', 'film'):0.125
# ('lack', 'origin'):0.1111111111111111
# ('origin', 'precis'):0.0625
# ('precis', 'plot'):1.0
# ('plot', 'sometim'):0.043478260869565216
# ('movi', 'confus'):0.004807692307692308
# ('confus', 'wander'):0.16666666666666666
# ('wander', 'aimlessli'):0.5
# ('aimlessli', 'that'):1.0
# ('that', 'fail'):0.07142857142857142
# ('fail', 'becom'):0.2
# ('becom', 'complet'):0.09090909090909091
# ('complet', 'cinemat'):0.06666666666666667
# ('cinemat', 'art'):0.6666666666666666
# ('art', 'rather'):0.1111111111111111
# ('rather', 'montagu'):0.3333333333333333
# ('montagu', 'eye'):1.0
# ('eye', 'plea'):0.25
# ('plea', 'scene'):0.16666666666666666
# ('scene', 'noth'):0.043478260869565216
# ('noth', 'overal'):0.1
# ('overal', 'despit'):0.09090909090909091
# ('despit', 'shortcom'):0.14285714285714285
# ('shortcom', 'movi'):1.0
# ('definit', 'one'):0.07692307692307693
# ('one', 'excit'):0.019230769230769232
# ('movi', 'year'):0.004807692307692308
# ('year', 'rating7510'):0.041666666666666664
# ('rating7510', 'one'):1.0
# ('one', 'prescreen'):0.019230769230769232
# ('prescreen', 'citi'):1.0
# ('citi', 'taken'):0.2
# ('taken', 'review'):0.5
# ('titl', 'give'):0.14285714285714285
# ('give', 'torn'):0.045454545454545456
# ('torn', 'ye'):1.0
# ('ye', 'joaquin'):0.1111111111111111
# ('phoenix', 'alway'):0.013513513513513514
# ('alway', 'verit'):0.2
# ('verit', 'action'):1.0
# ('action', 'talent'):0.05555555555555555
# ('talent', 'wast'):0.14285714285714285
# ('wast', 'role'):0.14285714285714285
# ('role', 'ye'):0.09090909090909091
# ('ye', 'phoenix'):0.1111111111111111
# ('portray', 'charact'):0.06666666666666667
# ('charact', 'riot'):0.017857142857142856
# ('riot', 'ye'):0.5
# ('ye', 'stori'):0.1111111111111111
# ('stori', 'grip'):0.02631578947368421
# ('grip', 'also'):0.5
# ('also', 'necessari'):0.045454545454545456
# ('necessari', 'especi'):1.0
# ('especi', 'today'):0.2
# ('today', 'seem'):0.25
# ('seem', 'mental'):0.06666666666666667
# ('ill', 'run'):0.034482758620689655
# ('run', 'rampart'):0.5
# ('rampart', 'ye'):1.0
# ('ye', 'tone'):0.1111111111111111
# ('tone', 'magnific'):0.3333333333333333
# ('magnific', 'set'):0.3333333333333333
# ('set', 'within'):0.14285714285714285
# ('within', 'cinemat'):0.3333333333333333
# ('art', 'direct'):0.1111111111111111
# ('direct', 'problem'):0.07142857142857142
# ('problem', 'way'):0.125
# ('way', 'tie'):0.029411764705882353
# ('univers', 'particularli'):0.14285714285714285
# ('particularli', 'common'):0.25
# ('common', 'differenti'):0.3333333333333333
# ('differenti', 'joke'):1.0
# ('joke', 'past'):0.006896551724137931
# ('past', 'still'):0.14285714285714285
# ('still', 'problem'):0.16666666666666666
# ('problem', 'make'):0.125
# ('make', 'two'):0.029411764705882353
# ('two', 'world'):0.1111111111111111
# ('world', 'merg'):0.1111111111111111
# ('merg', 'saw'):1.0
# ('saw', 'movi'):0.14285714285714285
# ('movi', 'open'):0.004807692307692308
# ('open', 'weekend'):0.5
# ('weekend', 'love'):1.0
# ('love', 'think'):0.125
# ('masterpiec', 'convinc'):0.047619047619047616
# ('convinc', '65'):0.16666666666666666
# ('65', 'year'):1.0
# ('year', 'old'):0.041666666666666664
# ('old', 'mother'):1.0
# ('mother', 'see'):0.25
# ('see', 'couldn'):0.03333333333333333
# ('couldn', 'even'):0.25
# ('even', 'rememb'):0.037037037037037035
# ('rememb', 'whose'):0.2
# ('whose', 'genesi'):0.25
# ('genesi', 'joke'):0.5
# ('joke', 'read'):0.006896551724137931
# ('read', 'neg'):0.25
# ('neg', 'press'):1.0
# ('press', 'movi'):0.5
# ('movi', 'violent'):0.004807692307692308
# ('violent', 'take'):0.1111111111111111
# ('take', 'light'):0.04
# ('light', 'mental'):0.2
# ('issu', 'love'):0.125
# ('love', 'movi'):0.125
# ('movi', 'sympath'):0.004807692307692308
# ('sympath', 'arthur'):0.2
# ('arthur', 'foot'):0.027777777777777776
# ('joke', 'certain'):0.006896551724137931
# ('certain', 'point'):0.3333333333333333
# ('point', 'surpris'):0.07142857142857142
# ('surpris', 'small'):0.3333333333333333
# ('small', 'amount'):1.0
# ('amount', 'violenc'):0.5
# ('violenc', 'depict'):0.125
# ('depict', 'press'):1.0
# ('press', 'putdown'):0.5
# ('putdown', 'enjoy'):1.0
# ('enjoy', 'social'):0.1111111111111111
# ('commentari', 'movi'):0.25
# ('movi', 'convey'):0.004807692307692308
# ('convey', 'score'):1.0
# ('score', '9'):0.05
# ('9', '10'):1.0
# ('10', 'mon'):0.25
# ('mon', 'alway'):0.3333333333333333
# ('alway', 'right'):0.2

# %%
whole_dataset = ''
index = []
i = 1
for line in df['After Lemmatization']:
  whole_dataset = whole_dataset + line
  value = 'Review-' + str(i)
  index.append(value)
  i += 1

# %%
import nltk
nltk.download('brown')
from textblob import TextBlob
noun_phrases = []
frequency = []
for line in df['After Lemmatization']:
  blob = TextBlob(line)
  for nouns in blob.noun_phrases:
    noun_phrases.append(nouns)
for word in noun_phrases:
  noun_phrases_freq = []
  for line in df['After Lemmatization']:
    noun_phrases_freq.append(line.count(word) / whole_dataset.count(word))
  frequency.append(noun_phrases_freq)
noun_phrases_df = pd.DataFrame(frequency).T
noun_phrases_df.columns = list(noun_phrases)
noun_phrases_df.index = index
noun_phrases_df
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
#             everi movi  impact joaquin  scenographi brillianc grotesqu hunt  \
# Review-1           1.0             1.0                                  1.0
# Review-2           0.0             0.0                                  0.0
# Review-3           0.0             0.0                                  0.0
# Review-4           0.0             0.0                                  0.0
# Review-5           0.0             0.0                                  0.0
# ...                ...             ...                                  ...
# Review-121         0.0             0.0                                  0.0
# Review-122         0.0             0.0                                  0.0
# Review-123         0.0             0.0                                  0.0
# Review-124         0.0             0.0                                  0.0
# Review-125         0.0             0.0                                  0.0
#
#             time mesmer wont blink eye  \
# Review-1                           1.0
# Review-2                           0.0
# Review-3                           0.0
# Review-4                           0.0
# Review-5                           0.0
# ...                                ...
# Review-121                         0.0
# Review-122                         0.0
# Review-123                         0.0
# Review-124                         0.0
# Review-125                         0.0
#
#             serious funni moment emot rollercoast sometim multipl emot  \
# Review-1                                                  1.0
# Review-2                                                  0.0
# Review-3                                                  0.0
# Review-4                                                  0.0
# Review-5                                                  0.0
# ...                                                       ...
# Review-121                                                0.0
# Review-122                                                0.0
# Review-123                                                0.0
# Review-124                                                0.0
# Review-125                                                0.0
#
#             typic actionriddl  superhero movi  \
# Review-1                  1.0            0.25
# Review-2                  0.0            0.00
# Review-3                  0.0            0.00
# Review-4                  0.0            0.00
# Review-5                  0.0            0.00
# ...                       ...             ...
# Review-121                0.0            0.00
# Review-122                0.0            0.00
# Review-123                0.0            0.00
# Review-124                0.0            0.00
# Review-125                0.0            0.00
#
#             proper psycholog thrillerdrama singl  alon isol truli relat  \
# Review-1                                     1.0                    0.0
# Review-2                                     0.0                    1.0
# Review-3                                     0.0                    0.0
# Review-4                                     0.0                    0.0
# Review-5                                     0.0                    0.0
# ...                                          ...                    ...
# Review-121                                   0.0                    0.0
# Review-122                                   0.0                    0.0
# Review-123                                   0.0                    0.0
# Review-124                                   0.0                    0.0
# Review-125                                   0.0                    0.0
#
#             sorri charact lot peopl  ...  masterpiec convinc  old mother  \
# Review-1                        0.0  ...                 0.0         0.0
# Review-2                        1.0  ...                 0.0         0.0
# Review-3                        0.0  ...                 0.0         0.0
# Review-4                        0.0  ...                 0.0         0.0
# Review-5                        0.0  ...                 0.0         0.0
# ...                             ...  ...                 ...         ...
# Review-121                      0.0  ...                 0.0         0.0
# Review-122                      0.0  ...                 0.0         0.0
# Review-123                      0.0  ...                 0.0         0.0
# Review-124                      0.0  ...                 0.0         0.0
# Review-125                      0.0  ...                 1.0         1.0
#
#             genesi joke  neg press movi  mental health issu  \
# Review-1            0.0             0.0                 0.0
# Review-2            0.0             0.0                 0.0
# Review-3            0.0             0.0                 0.0
# Review-4            0.0             0.0                 0.0
# Review-5            0.0             0.0                 0.0
# ...                 ...             ...                 ...
# Review-121          0.0             0.0                 0.0
# Review-122          0.0             0.0                 0.0
# Review-123          0.0             0.0                 0.0
# Review-124          0.0             0.0                 0.0
# Review-125          1.0             1.0                 0.5
#
#             movi sympath arthur foot joke  certain point surpris  \
# Review-1                              0.0                    0.0
# Review-2                              0.0                    0.0
# Review-3                              0.0                    0.0
# Review-4                              0.0                    0.0
# Review-5                              0.0                    0.0
# ...                                   ...                    ...
# Review-121                            0.0                    0.0
# Review-122                            0.0                    0.0
# Review-123                            0.0                    0.0
# Review-124                            0.0                    0.0
# Review-125                            1.0                    1.0
#
#             small amount violenc depict press putdown  social commentari movi  \
# Review-1                                          0.0                     0.0
# Review-2                                          0.0                     0.0
# Review-3                                          0.0                     0.0
# Review-4                                          0.0                     0.0
# Review-5                                          0.0                     0.0
# ...                                               ...                     ...
# Review-121                                        0.0                     0.0
# Review-122                                        0.0                     0.0
# Review-123                                        0.0                     0.0
# Review-124                                        0.0                     0.0
# Review-125                                        1.0                     1.0
#
#             mon alway
# Review-1          0.0
# Review-2          0.0
# Review-3          0.0
# Review-4          0.0
# Review-5          0.0
# ...               ...
# Review-121        0.0
# Review-122        0.0
# Review-123        0.0
# Review-124        0.0
# Review-125        1.0
#
# [125 rows x 1199 columns]

# %% [markdown]
# # **Question 2: Undersand TF-IDF and Document representation**

# %% [markdown]
# (20 points). Starting from the documents (all the reviews, or abstracts, or tweets) collected for assignment two, write a python program:
#
# (1) To build the **documents-terms weights (tf*idf) matrix bold text**.
#
# (2) To rank the documents with respect to query (design a query by yourself, for example, "An Outstanding movie with a haunting performance and best character development") by using **cosine similarity**.

# %%
# Write your code here
# Write your code here
import math
def tf_idf_value(sentence,word):
  size = len(sentence.split(" "))
  tf_value = sentence.count(word)/size
  idf_value = 0
  if(tf_value!=0):
    idf_value = math.log(size)/sentence.count(word)
  else:
    return 0;
  return tf_value*idf_value

sentences = df["Spelling Correction"].values.tolist()
tokens_list = set([j for i in sentences for j in i.split(" ")])
tf_idf = pd.DataFrame(tokens_list,columns=["token"])
count = 0
for i in sentences:
  tf_idf[str(count)] = tf_idf["token"].apply(lambda x : tf_idf_value(i,x))
  count+=1

tf_idf
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#            token         0         1         2        3         4         5  \
# 0                 0.081918  0.093937  0.055855  0.08065  0.083231  0.058163
# 1       replaces  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 2         viewer  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 3      contrived  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 4        subways  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# ...          ...       ...       ...       ...      ...       ...       ...
# 2333  restaurant  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 2334  colorshues  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 2335     bridges  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 2336       thing  0.000000  0.000000  0.055855  0.00000  0.000000  0.058163
# 2337     edition  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
#
#              6         7         8  ...       115       116  117  118  \
# 0     0.110774  0.035297  0.070931  ...  0.047936  0.020007  0.0  0.0
# 1     0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.0  0.0
# 2     0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.0  0.0
# 3     0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.0  0.0
# 4     0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.0  0.0
# ...        ...       ...       ...  ...       ...       ...  ...  ...
# 2333  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.0  0.0
# 2334  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.0  0.0
# 2335  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.0  0.0
# 2336  0.000000  0.000000  0.000000  ...  0.000000  0.020007  0.0  0.0
# 2337  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.0  0.0
#
#            119  120       121       122       123       124
# 0     0.298627  0.0  0.088992  0.027041  0.070008  0.072861
# 1     0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2     0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 3     0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 4     0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# ...        ...  ...       ...       ...       ...       ...
# 2333  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2334  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2335  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2336  0.000000  0.0  0.000000  0.027041  0.000000  0.000000
# 2337  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
#
# [2338 rows x 126 columns]

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
query_sentence = 'Shang-Chi and the Legend of the Ten Rings is an Action - Fantasy movie in which we watch a new era of Marvel Studios rise with Shang-Chi,the master of Kung Fu. He has to face his past involving him with the Ten Rings organization and crate his future accordingly.Finally, I have to say that "Shang-Chi and the Legend of the Ten Rings" is an amazing movie and I strongly recommend everyone to watch it, especially the fans of Marvel.'
X_list = word_tokenize(query_sentence)
sw = stopwords.words('english') 
X_set = {w for w in X_list if not w in sw}

# %%
def compute_vector(X_set, Y_set):
  rvector = X_set.union(Y_set)
  l1 =[];l2 =[]
  for w in rvector: 
      if w in X_set: l1.append(1)
      else: l1.append(0) 
      if w in Y_set: l2.append(1) 
      else: l2.append(0)
  return rvector, l1, l2

# %%
def compute_cosine(rvector, l1, l2):
  c = 0
  for i in range(len(rvector)): 
        c+= l1[i]*l2[i] 
  cosine = c / float((sum(l1)*sum(l2))**0.5) 
  return cosine

# %%
similarity_list = []
for sentence in df['Spelling Correction']:
  Y_list = word_tokenize(sentence)
  Y_set = {w for w in Y_list if not w in sw}
  rvector, l1, l2 = compute_vector(X_set, Y_set)
  try:
    similarity = compute_cosine(rvector, l1, l2)
  except ZeroDivisionError:
    similarity = 'None'
  similarity_list.append(similarity)
cosine_dataframe = pd.DataFrame(list(zip(df['Review'],similarity_list)), columns=['Reviews','Cosine Similarity'])
cosine_dataframe
# Out:
#                                                Reviews Cosine Similarity
# 0    Every once in a while a movie comes, that trul...          0.048479
# 1    This is a movie that only those who have felt ...          0.057236
# 2    Truly a masterpiece, The Best Hollywood film o...               0.0
# 3    Joaquin Phoenix gives a tour de force performa...          0.025367
# 4    Most of the time movies are anticipated like t...           0.05135
# ..                                                 ...               ...
# 120                                                                 None
# 121  This film surpassed all other films in portray...            0.0274
# 122  A confused representation of insanity from a p...           0.02641
# 123  While we were at one of the only pre-screening...          0.044744
# 124  I saw the movie after the opening weekend and ...          0.023729
#
# [125 rows x 2 columns]

# %% [markdown]
# # **Question 3: Create your own word embedding model**

# %% [markdown]
# (20 points). Use the data you collected for assignment two to build a word embedding model:
#
# (1) Train a 300-dimension word embedding (it can be word2vec, glove, ulmfit, bert, or others).
#
# (2) Visualize the word embedding model you created.
#
# Reference: https://machinelearningmastery.com/develop-word-embeddings-python-gensim/

# %%
# Write your code here
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install selenium
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:3 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Ign:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:14 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:15 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [82.3 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,694 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,490 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [884 kB]
# Get:19 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,831 kB]
# Get:21 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [938 kB]
# Get:22 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [952 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [29.8 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,133 kB]
# Get:25 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [45.3 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,268 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [918 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-backports/main amd64 Packages [12.2 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [12.9 kB]
# Get:30 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [44.3 kB]
# Fetched 15.6 MB in 5s (3,224 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 96 not upgraded.
# Need to get 88.3 MB of archives.
# After this operation, 294 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 99.0.4844.84-0ubuntu0.18.04.1 [1,142 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser amd64 99.0.4844.84-0ubuntu0.18.04.1 [77.7 MB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser-l10n all 99.0.4844.84-0ubuntu0.18.04.1 [4,397 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-chromedriver amd64 99.0.4844.84-0ubuntu0.18.04.1 [5,092 kB]
# Fetched 88.3 MB in 3s (27.9 MB/s)
# Selecting previously unselected package chromium-codecs-ffmpeg-extra.
# (Reading database ... 156210 files and directories currently installed.)
# Preparing to unpack .../chromium-codecs-ffmpeg-extra_99.0.4844.84-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-codecs-ffmpeg-extra (99.0.4844.84-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser.
# Preparing to unpack .../chromium-browser_99.0.4844.84-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-browser (99.0.4844.84-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser-l10n.
# Preparing to unpack .../chromium-browser-l10n_99.0.4844.84-0ubuntu0.18.04.1_all.deb ...
# Unpacking chromium-browser-l10n (99.0.4844.84-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_99.0.4844.84-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-chromedriver (99.0.4844.84-0ubuntu0.18.04.1) ...
# Setting up chromium-codecs-ffmpeg-extra (99.0.4844.84-0ubuntu0.18.04.1) ...
# Setting up chromium-browser (99.0.4844.84-0ubuntu0.18.04.1) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-chromedriver (99.0.4844.84-0ubuntu0.18.04.1) ...
# Setting up chromium-browser-l10n (99.0.4844.84-0ubuntu0.18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file
# Collecting selenium
#   Downloading selenium-4.1.3-py3-none-any.whl (968 kB)
#      |████████████████████████████████| 968 kB 23.6 MB/s
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Collecting urllib3[secure,socks]~=1.26
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 36.3 MB/s
# Collecting trio~=0.17
#   Downloading trio-0.20.0-py3-none-any.whl (359 kB)
#      |████████████████████████████████| 359 kB 42.7 MB/s
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.10)
# Collecting outcome
#   Downloading outcome-1.1.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (21.4.0)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.1.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from urllib3[secure,socks]~=1.26->selenium) (2021.10.8)
# Collecting cryptography>=1.3.4
#   Downloading cryptography-36.0.2-cp36-abi3-manylinux_2_24_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 40.7 MB/s
# Collecting pyOpenSSL>=0.14
#   Downloading pyOpenSSL-22.0.0-py2.py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 3.5 MB/s
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium) (2.21)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.13.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 5.4 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from h11<1,>=0.9.0->wsproto>=0.14->trio-websocket~=0.9->selenium) (3.10.0.2)
# Installing collected packages: sniffio, outcome, h11, cryptography, async-generator, wsproto, urllib3, trio, pyOpenSSL, trio-websocket, selenium
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.9 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed async-generator-1.10 cryptography-36.0.2 h11-0.13.0 outcome-1.1.0 pyOpenSSL-22.0.0 selenium-4.1.3 sniffio-1.2.0 trio-0.20.0 trio-websocket-0.9.2 urllib3-1.26.9 wsproto-1.1.0

# %%
from selenium import webdriver #importing selenium package
options = webdriver.ChromeOptions()
options.add_argument('-headless')
options.add_argument('-no-sandbox')
options.add_argument('-disable-dev-shm-usage')

# %%
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.common.by import By
import pandas as pd
import time

driver = webdriver.Chrome('chromedriver',options=options)
link = 'https://www.imdb.com/title/tt7286456/reviews?ref_=tt_urv'
title_array = []
review_array = []
driver.get(link)
for num in range(4):
  driver.find_element_by_class_name("ipl-load-more__button").click()
  time.sleep(5)
  listOfTitle = driver.find_elements(By.CLASS_NAME, "title")
  listOfReviews = driver.find_elements(By.CLASS_NAME, "text")
for ele, sub_ele in zip(listOfTitle, listOfReviews):
      title_array.append((ele.text).replace('\n',''))
      review_array.append(sub_ele.text)
df = pd.DataFrame(list(zip(title_array, review_array)), columns =['Title', 'Review'])
print("Length of data frame is {0}".format(len(df)))
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   if sys.path[0] == '':
# Length of data frame is 125
#                                                  Title  \
# 0    Outstanding movie with a haunting performance ...
# 1                       Only certain people can relate
# 2                             Perfect in every aspect.
# 3                                        MASTERPIECE 😍
# 4                                     The Hype is real
# ..                                                 ...
# 120                      Best film in the 21st century
# 121                                           a mirror
# 122                                      Amazing movie
# 123  Arthur Fleck: a case study of a young person's...
# 124  A gorgeously crafted baroque film with a sheer...
#
#                                                 Review
# 0    Every once in a while a movie comes, that trul...
# 1    This is a movie that only those who have felt ...
# 2    Truly a masterpiece, The Best Hollywood film o...
# 3    Joaquin Phoenix gives a tour de force performa...
# 4    Most of the time movies are anticipated like t...
# ..                                                 ...
# 120
# 121  In many aspects, it is a mirror. For society, ...
# 122  Best acting and story. This is an Oscar winnin...
# 123  This film surpassed all other films in portray...
# 124  A confused representation of insanity from a p...
#
# [125 rows x 2 columns]

# %%
list2 = []
for i in df.index:
    y = str(df["Review"][i]).split()
    list2.append(y)

# %%
model2 = Word2Vec(list2, size = 300)
print(model2)
# Out:
# Word2Vec(vocab=395, size=300, alpha=0.025)

# %%
words2 = list(model2.wv.vocab)

# %%
words2
# Out:
# ['in',
#  'a',
#  'while',
#  'movie',
#  'that',
#  'truly',
#  'makes',
#  'an',
#  "Joaquin's",
#  'performance',
#  'and',
#  'all',
#  "it's",
#  'to',
#  'watch',
#  'at',
#  'but',
#  'so',
#  'you',
#  'watching',
#  'it.',
#  'with',
#  '-',
#  'multiple',
#  'emotions',
#  'the',
#  'same',
#  'time.',
#  'this',
#  'is',
#  'far',
#  'from',
#  'proper',
#  'psychological',
#  'best',
#  'character',
#  'I',
#  'have',
#  'ever',
#  'This',
#  'only',
#  'those',
#  'who',
#  'felt',
#  'can',
#  'You',
#  'understand',
#  'feel',
#  'for',
#  'character.',
#  'A',
#  'lot',
#  'of',
#  'people',
#  'will',
#  'see',
#  'think',
#  'it',
#  'But',
#  'should',
#  'each',
#  'every',
#  'one',
#  'us',
#  'become',
#  'better',
#  'everyone',
#  'make',
#  'other',
#  'like',
#  'they',
#  'instead',
#  'making',
#  'them',
#  'The',
#  'Best',
#  'Hollywood',
#  'film',
#  'films',
#  'And',
#  'comic',
#  'book',
#  'real',
#  'are',
#  'find',
#  "It's",
#  'about',
#  'society',
#  'people,',
#  'do',
#  'something',
#  'way',
#  'shows',
#  'class',
#  'how',
#  'around',
#  'not',
#  "that's",
#  'what',
#  'There',
#  'could',
#  'be',
#  'our',
#  'much',
#  'than',
#  'up',
#  'first',
#  'film.',
#  'Joaquin',
#  'Phoenix',
#  'gives',
#  'performance,',
#  'its',
#  'talk',
#  'without',
#  'Heath',
#  'Dark',
#  'portrayal',
#  'Joker,',
#  'fact',
#  'going',
#  'by',
#  'because',
#  'many',
#  'thought',
#  'time',
#  'movies',
#  'Joker',
#  'was',
#  'more',
#  'as',
#  'say',
#  'We',
#  'seen',
#  'If',
#  'we',
#  'Phillips',
#  'dark',
#  'villain',
#  'bad',
#  'me',
#  'start',
#  'off',
#  'saying',
#  'if',
#  "doesn't",
#  'get',
#  'his',
#  'Oscar',
#  'movie.',
#  'amazing',
#  'review',
#  'Todd',
#  'story',
#  'he',
#  'takes',
#  'just',
#  'score',
#  'came',
#  'very',
#  'It',
#  'Taxi',
#  'Driver',
#  'King',
#  'got',
#  'scenes',
#  'violent',
#  'needs',
#  'why',
#  'some',
#  'need',
#  "Arthur's",
#  'come',
#  'on',
#  'point',
#  'never',
#  'be.',
#  'masterpiece',
#  'cinematography',
#  'had',
#  'definitely',
#  'worth',
#  'cinema',
#  'form',
#  'or',
#  'movie,',
#  'most',
#  'genre',
#  'main',
#  'does',
#  'almost',
#  'take',
#  'good.',
#  'joker',
#  "Phoenix's",
#  'being',
#  'superhero',
#  'Knight',
#  'good',
#  'film,',
#  'too',
#  'also',
#  'somewhat',
#  'am',
#  'quite',
#  'win',
#  'u',
#  'really',
#  'interesting',
#  'acting',
#  'Do',
#  '5',
#  'To',
#  'your',
#  'put',
#  'While',
#  "I've",
#  'watched',
#  'down',
#  'great',
#  'They',
#  "don't",
#  'mean',
#  'What',
#  'into',
#  'man',
#  'him',
#  'made',
#  'When',
#  'He',
#  'has',
#  'Batman',
#  'getting',
#  'plot',
#  'excellent',
#  'hype',
#  'bit',
#  'throughout',
#  'In',
#  'no',
#  'did',
#  'though',
#  'reviews',
#  'based',
#  'want',
#  'joker.',
#  'would',
#  'high',
#  'maybe',
#  'poor',
#  'Joker.',
#  'realistic',
#  'important',
#  'know',
#  'when',
#  "isn't",
#  'That',
#  'you,',
#  'then',
#  'acting,',
#  'itself',
#  'deserves',
#  'went',
#  '&',
#  'feels',
#  '2',
#  'version',
#  'At',
#  'hours',
#  'DC',
#  'right',
#  'times',
#  'long',
#  'boring.',
#  'person',
#  'there',
#  'which',
#  'years',
#  'were',
#  'saw',
#  'my',
#  'masterpiece.',
#  'whole',
#  'Not',
#  'action',
#  'may',
#  'true',
#  'art',
#  'over',
#  'story,',
#  'their',
#  'here',
#  'actor',
#  'took',
#  'different',
#  'any',
#  'actors',
#  'life',
#  'own',
#  'hyped',
#  'out',
#  'nor',
#  'actually',
#  'great.',
#  'even',
#  'left',
#  'music',
#  'average',
#  'through',
#  'been',
#  'more.',
#  'story.',
#  'done',
#  'iconic',
#  'nothing',
#  'little',
#  'attention',
#  'less',
#  'mental',
#  'health',
#  'it,',
#  'absolutely',
#  'kind',
#  'anything',
#  'entire',
#  'perfect',
#  'where',
#  'seem',
#  'new',
#  'last',
#  'back',
#  'mentally',
#  'ill',
#  'away',
#  'looking',
#  'feeling',
#  'moments',
#  'scene',
#  'these',
#  "wasn't",
#  'completely',
#  "Don't",
#  'told',
#  "I'm",
#  'trying',
#  'illness',
#  'Ledger',
#  'One',
#  'origin',
#  "didn't",
#  'until',
#  'Overall,',
#  'such',
#  'beautiful',
#  'part',
#  'slow',
#  'anyone',
#  'brilliant',
#  'money',
#  ':',
#  ',',
#  'job',
#  'two',
#  'complete',
#  'director',
#  'well',
#  'lacks',
#  'performances',
#  'after',
#  'clown',
#  'before',
#  'go',
#  'Arthur',
#  'Fleck',
#  'boring',
#  "he's",
#  'laugh',
#  'show',
#  'Gotham',
#  'De',
#  'Niro',
#  'writing',
#  '"Joker"',
#  'role',
#  'Murray',
#  'all,',
#  'worked',
#  'direction',
#  'i',
#  'unstable',
#  'Wayne',
#  'sure',
#  "Joker's",
#  'hard',
#  'n']

# %%
# fit a 2d PCA model to the vectors
from sklearn.decomposition import PCA

X = model2[model2.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(X)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   after removing the cwd from sys.path.

# %%
# create a scatter plot of the projection
import matplotlib.pyplot as plt
plt.figure (figsize = (20,10))
plt.scatter(result[:, 0], result[:, 1])
words = list(model2.wv.vocab)
for i, word in enumerate(words):
	plt.annotate(word, xy=(result[i, 0], result[i, 1]))
plt.show()

# %% [markdown]
# # **Question 4: Create your own training and evaluation data for sentiment analysis**

# %% [markdown]
# (15 points). **You dodn't need to write program for this question!** Read each review (abstract or tweet) you collected in detail, and annotate each review with a sentiment (positive, negative, or neutral). Save the annotated dataset into a csv file with three columns (first column: document_id, clean_text, sentiment), upload the csv file to GitHub and submit the file link blew. This datset will be used for assignment four: sentiment analysis and text classification.

# %%
# The GitHub link of your final csv file



# Link: https://github.com/nivemula/Nithin_INFO5731_Spring2022/blob/main/sentimentalAnalysis.csv
